# %%
DATABASE_URL = "mssql+pyodbc://oleksii:sdjnn4393vn@194.76.26.191/FLIPCLOUD?driver=ODBC+Driver+17+for+SQL+Server"

SCOPE_ID = 26

# %%
from sqlalchemy import text
from datetime import datetime

def gather_all_scheduling_data(scope_id, start_date, end_date, max_tasks=50):
    """
    Gathers core scheduling data for an optimization:
      1) Processes/Tasks within [start_date, end_date].
      2) Equipment from RESSOURCE/typeressource.
      3) Workers + shifts from PERSONNEL/FLIPSHIFT.

    Returns a dict:
    {
      "processes": [ {process/task info}, ... ],
      "equipment": [ {equipment info}, ... ],
      "workers": { worker_id: { 'firstName':..., 'team_name':...}, ... },
      "shifts": { worker_id: [(shift_start, shift_end, shift_date), ...], ... }
    }

    - scope_id: Your scope integer
    - start_date, end_date: Python datetime objects
    - max_tasks: limit tasks for testing (defaults to 50)
    """

    # 1) Processes in date range
    #    We join PROCESS + PROCESSACTIVITY + COREMATRIX + planningLine
    process_query = text(f"""
            SELECT
                pa.pra_pro_fk as process_id,
                pr.PRO_NAME as process_name,
                va.act_id,
                va.act_name,
                va.act_category,
                va.act_workload,
                va.defaultStatus,
                va.workCadence,
                va.workersPerBox,
                va.prefweekend,
                va.block_zone,
                pa.pra_seq,
                pa.pra_groupnum,
                pa.pra_interval,
                pa.pra_max_interval,
                pa.pra_start_interval,
                pa.pra_workload,
                pa.PRA_PARA_ALIGN,
                ISNULL((
                    SELECT ar2.ACR_QTY, ar2.ACR_OPTION, r2.RE_NAME, r2.RE_TYPE
                    FROM actressource ar2
                    JOIN ressource r2 ON ar2.acr_ress_fk = r2.re_pk
                    WHERE va.act_id = ar2.acr_cm_fk AND r2.re_type = 'TEAM'
                    FOR JSON PATH
                ), '[]') as requiredWorkers,
                r.RE_TYPE as resource_type,
                r.RE_NAME as resource_name,
                r.RE_PK as resource_id,
                tr.tr_name as equipment_category,
                ar.ACR_QTY as resource_quantity,
                ISNULL(ar.ACR_OPTION, 'auto') as resource_option,
                ar.ACR_WORKLOAD as equip_workload,
                MIN(pl.pll_datestart) OVER (PARTITION BY pa.pra_pro_fk) as start_date,
                MAX(pl.pll_datestop) OVER (PARTITION BY pa.pra_pro_fk) as end_date
            FROM processactivity pa
            JOIN v_activity va ON pa.PRA_ACT_FK = va.act_id
            LEFT JOIN actressource ar ON va.act_id = ar.acr_cm_fk
            LEFT JOIN ressource r ON ar.acr_ress_fk = r.re_pk
            LEFT JOIN typeressource tr ON r.re_resstype_fk = tr.tr_pk
            JOIN planningline pl ON pa.pra_pro_fk = pl.pll_pro_fk
            JOIN process pr ON pa.pra_pro_fk = pr.PRO_PK
            WHERE va.act_scope = :scope_id
            AND pl.pll_datestart >= :start_date
            AND pl.pll_datestop <= :end_date
            ORDER BY pa.pra_seq
    """)

    # 2) Equipment data
    equipment_query = text("""
        SELECT
            r.RE_PK as equipment_id,
            r.RE_NAME as equipment_name,
            r.RE_TYPE as equipment_type,
            tr.tr_name as category,
            r.re_maint_required as maintenanceRequired,
            r.re_parent as parent_zone
        FROM RESSOURCE r
        JOIN typeressource tr ON r.re_resstype_fk = tr.tr_pk
        WHERE r.RE_SCOPE_FK = :scope_id
          AND r.RE_TYPE = 'EQUIPEMENT'
    """)
    
    zone_query = text("""
        SELECT
            r.RE_PK as zone_id,
            r.RE_NAME as zone_name,
            r.RE_TYPE as zone_type,
            tr.tr_name as category,
            r.re_maint_required as maintenanceRequired,
            r.re_parent as parent_zone
        FROM RESSOURCE r
        JOIN typeressource tr ON r.re_resstype_fk = tr.tr_pk
        WHERE r.RE_SCOPE_FK = :scope_id
          AND r.RE_TYPE = 'ZONE'
    """)

    # 3) Workers + shifts
    workers_query = text("""
        SELECT
          p.PERS_PK as worker_id,
          p.PERS_FIRSTNAME as firstName,
          p.PERS_LASTNAME  as lastName,
          p.PERS_FILTER3   as team_name
        FROM PERSONNEL p
        JOIN AGGREGATION a ON a.AGG_PERS_FK = p.PERS_PK
        WHERE a.agg_plan_fk = :scope_id
    """)

    shifts_query = text("""
        SELECT
          fs.SH_PERS_FK as worker_id,
          fs.SH_DATE as shift_date,
          fs.SH_START as shift_start,
          CASE WHEN fs.SH_STOP > fs.SH_START THEN fs.SH_STOP
               ELSE fs.SH_STOP + 1440
          END as shift_end
        FROM FLIPSHIFT fs
        WHERE fs.sh_scope_fk = :scope_id
    """)

    # Execute the queries
    with engine.connect() as conn:
        # Processes
        proc_result = conn.execute(
            process_query,
            {"scope_id": scope_id, "start_date": start_date, "end_date": end_date}
        ).mappings().all()
        processes_data = [dict(r) for r in proc_result]

        # Equipment
        equip_result = conn.execute(
            equipment_query, {"scope_id": scope_id}
        ).mappings().all()
        equipment_data = [dict(r) for r in equip_result]
        
        zone_result = conn.execute(
            zone_query, {"scope_id": scope_id}
        ).mappings().all()
        zones = [dict(r) for r in zone_result]

        # Workers
        worker_result = conn.execute(
            workers_query, {"scope_id": scope_id}
        ).mappings().all()

        # Convert to dict { worker_id: {...} }
        workers_data = {}
        for w in worker_result:
            wdict = dict(w)
            wid = wdict["worker_id"]
            workers_data[wid] = {
                "firstName": wdict["firstName"],
                "lastName":  wdict["lastName"],
                "team_name": wdict["team_name"]
            }

        # Shifts
        shift_result = conn.execute(
            shifts_query, {"scope_id": scope_id}
        ).mappings().all()

        # Convert to dict { worker_id: [ (shift_start, shift_end, shift_date), ... ] }
        shifts_map = {}
        for s in shift_result:
            sdict = dict(s)
            wid   = sdict["worker_id"]
            if wid not in shifts_map:
                shifts_map[wid] = []
            shifts_map[wid].append((
                sdict["shift_start"],
                sdict["shift_end"],
                sdict["shift_date"]
            ))

    # Return everything in one big dictionary
    return {
        "processes": processes_data,
        "equipment": equipment_data,
        "zones" : zones,
        "workers":   workers_data,
        "shifts":    shifts_map
    }

# %%
check_process_count_query = text("""
    SELECT
        CAST(pl.pll_datestart AS DATE) AS the_date,
        COUNT(DISTINCT pa.pra_pro_fk) AS num_processes
    FROM processactivity AS pa
    JOIN planningline   AS pl ON pa.pra_pro_fk = pl.pll_pro_fk
    JOIN process        AS pr ON pa.pra_pro_fk = pr.PRO_PK
    JOIN v_activity     AS va ON pa.PRA_ACT_FK = va.act_id
    WHERE va.act_scope = :scope_id
    GROUP BY CAST(pl.pll_datestart AS DATE)
    ORDER BY the_date
""")

with engine.connect() as conn:
    result = conn.execute(
        check_process_count_query,
        {"scope_id": 26}
    ).mappings().all()

    for row in result:
        print(row["the_date"], row["num_processes"])
# Out:
# 2021-02-14 2
# 2021-02-15 2
# 2021-02-16 1
# 2021-02-17 1
# 2021-02-18 3
# 2021-02-19 4
# 2021-02-20 2
# 2021-02-21 4
# 2021-02-22 2
# 2021-02-23 2
# 2021-02-24 2
# 2021-02-25 2
# 2021-02-26 2
# 2021-02-27 3
# 2021-02-28 2
# 2021-03-01 1
# 2021-03-02 1
# 2021-03-03 1
# 2021-03-04 1
# 2021-03-05 1
# 2021-03-06 2
# 2021-03-07 2
# 2021-03-08 3
# 2021-03-09 3
# 2021-03-10 4
# 2021-03-11 6
# 2021-03-12 2
# 2021-03-13 2
# 2021-03-14 1
# 2021-03-15 2
# 2021-03-16 4
# 2021-03-17 4
# 2021-03-18 3
# 2021-03-19 3
# 2021-03-20 4
# 2021-03-21 2
# 2021-03-22 5
# 2021-03-23 4
# 2021-03-24 3
# 2021-03-25 3
# 2021-03-26 3
# 2021-03-27 1
# 2021-03-28 1
# 2021-03-29 5
# 2021-03-30 4
# 2021-03-31 3
# 2021-04-01 3
# 2021-04-02 1
# 2021-04-03 1
# 2021-04-04 2
# 2021-04-05 3
# 2021-04-06 2
# 2021-04-07 3
# 2021-04-08 3
# 2021-04-09 1
# 2021-04-11 1
# 2021-04-12 1
# 2021-04-13 2
# 2021-04-14 4
# 2021-04-15 3
# 2021-04-16 2
# 2021-04-17 1
# 2021-04-19 3
# 2021-04-20 3
# 2021-04-21 3
# 2021-04-22 4
# 2021-04-23 4
# 2021-04-24 3
# 2021-04-25 1
# 2021-04-26 2
# 2021-04-27 2
# 2021-04-28 2
# 2021-04-30 2
# 2021-05-03 2
# 2021-05-04 1
# 2021-05-05 2
# 2021-05-06 2
# 2021-05-07 2
# 2021-05-08 2
# 2021-05-09 2
# 2021-05-17 1
# 2021-05-18 1
# 2021-05-19 1
# 2021-05-20 1
# 2021-05-21 1
# 2021-05-22 1
# 2021-05-23 1
# 2021-05-25 1
# 2021-05-26 1
# 2021-06-02 1
# 2021-06-03 1
# 2021-06-04 1
# 2021-06-05 1
# 2021-06-06 3
# 2021-06-07 3
# 2021-06-08 1
# 2021-06-09 3
# 2021-06-10 6
# 2021-06-11 4
# 2021-06-14 3
# 2021-06-15 2
# 2021-06-16 3
# 2021-06-17 3
# 2021-06-18 1
# 2021-06-19 1
# 2021-06-20 2
# 2021-06-21 2
# 2021-06-22 1
# 2021-06-23 3
# 2021-06-24 2
# 2021-06-25 1
# 2021-06-26 2
# 2021-06-27 3
# 2021-06-28 5
# 2021-06-29 5
# 2021-06-30 2
# 2021-07-01 2
# 2021-07-02 1
# 2021-07-03 1
# 2021-07-04 1
# 2021-07-05 2
# 2021-07-06 1
# 2021-07-07 3
# 2021-07-08 3
# 2021-07-09 1
# 2021-07-10 2
# 2021-07-11 1
# 2021-07-13 2
# 2021-07-14 1
# 2021-07-15 1
# 2021-07-16 2
# 2021-07-17 1
# 2021-07-18 3
# 2021-07-19 2
# 2021-07-20 3
# 2021-07-21 1
# 2021-07-22 2
# 2021-07-23 4
# 2021-07-24 2
# 2021-07-25 2
# 2021-07-26 2
# 2021-07-27 4
# 2021-07-28 3
# 2021-07-29 2
# 2021-07-30 2
# 2021-07-31 1
# 2021-08-01 1
# 2021-08-28 2
# 2021-08-29 1
# 2021-08-30 1
# 2021-09-01 2
# 2021-09-03 3
# 2021-09-04 1
# 2021-09-05 1
# 2021-09-06 1
# 2021-09-07 1
# 2021-09-08 1
# 2021-09-09 1
# 2021-09-10 1
# 2021-09-11 2
# 2021-09-12 2
# 2021-09-13 2
# 2021-09-14 4
# 2021-09-15 5
# 2021-09-16 5
# 2021-09-17 2
# 2021-09-18 1
# 2021-09-19 1
# 2021-09-20 3
# 2021-09-21 4
# 2021-09-22 4
# 2021-09-23 3
# 2021-09-24 4
# 2021-09-25 2
# 2021-09-27 3
# 2021-09-28 1
# 2021-09-29 2
# 2021-09-30 2
# 2021-10-01 3
# 2021-10-02 2
# 2021-10-03 2
# 2021-10-04 3
# 2021-10-05 4
# 2021-10-06 4
# 2021-10-07 2
# 2021-10-08 3
# 2021-10-09 3
# 2021-10-10 3
# 2021-10-11 3
# 2021-10-12 5
# 2021-10-13 3
# 2021-10-14 3
# 2021-10-15 2
# 2021-10-16 2
# 2021-10-17 2
# 2021-10-18 1
# 2021-10-19 4
# 2021-10-20 3
# 2021-10-21 2
# 2021-10-22 2
# 2021-10-23 1
# 2021-10-24 1
# 2021-10-25 2
# 2021-10-26 1
# 2021-10-27 2
# 2021-10-28 2
# 2021-10-29 2
# 2021-10-30 1
# 2021-11-01 1
# 2021-11-02 1
# 2021-11-03 1
# 2021-11-04 2
# 2021-11-05 3
# 2021-11-06 5
# 2021-11-07 4
# 2021-11-08 3
# 2021-11-09 3
# 2021-11-10 3
# 2021-11-11 4
# 2021-11-12 5
# 2021-11-13 4
# 2021-11-14 3
# 2021-11-15 2
# 2021-11-16 6
# 2021-11-17 6
# 2021-11-18 4
# 2021-11-19 2
# 2021-11-20 2
# 2021-11-21 5
# 2021-11-22 6
# 2021-11-23 5
# 2021-11-24 3
# 2021-11-25 4
# 2021-11-26 4
# 2021-11-27 3
# 2021-11-28 2
# 2021-11-29 3
# 2021-11-30 4
# 2021-12-01 2
# 2021-12-02 3
# 2021-12-03 6
# 2021-12-04 4
# 2021-12-05 4
# 2021-12-06 1
# 2021-12-07 5
# 2021-12-08 5
# 2021-12-09 3
# 2021-12-10 2
# 2021-12-11 3
# 2021-12-12 5
# 2021-12-13 5
# 2021-12-14 3
# 2021-12-15 1
# 2021-12-16 3
# 2021-12-17 4
# 2021-12-18 5
# 2021-12-19 3
# 2021-12-20 1
# 2021-12-21 1
# 2021-12-22 2
# 2021-12-23 2
# 2021-12-24 1
# 2022-01-05 1
# 2022-01-06 1
# 2022-01-07 1
# 2022-01-08 1
# 2022-01-09 1
# 2022-01-10 1
# 2022-01-11 1
# 2022-01-12 1
# 2022-01-13 1
# 2022-01-14 1
# 2022-01-15 1
# 2022-01-16 1
# 2022-01-19 2
# 2022-01-20 4
# 2022-01-21 4
# 2022-01-22 2
# 2022-01-23 1
# 2022-01-24 3
# 2022-01-25 1
# 2022-01-26 2
# 2022-01-27 1
# 2022-01-28 1
# 2022-01-29 2
# 2022-01-30 2
# 2022-01-31 1
# 2022-02-01 1
# 2022-02-04 1
# 2022-02-05 1
# 2022-02-08 2
# 2022-02-09 2
# 2022-02-10 2
# 2022-02-11 1
# 2022-02-12 1
# 2022-02-13 2
# 2022-02-14 2
# 2022-02-15 3
# 2022-02-16 2
# 2022-02-17 2
# 2022-02-18 2
# 2022-02-19 1
# 2022-02-20 1
# 2022-02-21 2
# 2022-02-22 2
# 2022-02-23 1
# 2022-02-24 1
# 2022-02-25 1
# 2022-02-26 1
# 2022-02-27 4
# 2022-02-28 4
# 2022-03-01 5
# 2022-03-02 2
# 2022-03-03 3
# 2022-03-04 3
# 2022-03-05 2
# 2022-03-06 1
# 2022-03-07 1
# 2022-03-08 2
# 2022-03-09 2
# 2022-03-10 2
# 2022-03-11 2
# 2022-03-12 2
# 2022-03-13 2
# 2022-03-14 2
# 2022-03-15 2
# 2022-03-16 3
# 2022-03-17 3
# 2022-03-18 3
# 2022-03-19 2
# 2022-03-20 2
# 2022-03-21 3
# 2022-03-22 4
# 2022-03-23 4
# 2022-03-24 4
# 2022-03-25 3
# 2022-03-26 4
# 2022-03-27 2
# 2022-03-28 2
# 2022-03-29 3
# 2022-03-30 3
# 2022-03-31 3
# 2022-04-01 3
# 2022-04-02 2
# 2022-04-03 2
# 2022-04-04 2
# 2022-04-05 2
# 2022-04-06 2
# 2022-04-07 2
# 2022-04-08 3
# 2022-04-09 3
# 2022-04-10 2
# 2022-04-11 2
# 2022-04-12 1
# 2022-04-13 1
# 2022-04-14 2
# 2022-04-15 2
# 2022-04-16 3
# 2022-04-17 2
# 2022-04-19 2
# 2022-04-20 4
# 2022-04-21 2
# 2022-04-22 3
# 2022-04-23 4
# 2022-04-24 4
# 2022-04-25 5
# 2022-04-26 4
# 2022-04-27 3
# 2022-04-28 5
# 2022-04-29 6
# 2022-04-30 5
# 2022-05-02 2
# 2022-05-03 6
# 2022-05-04 2
# 2022-05-05 3
# 2022-05-06 4
# 2022-05-07 2
# 2022-05-08 2
# 2022-05-09 3
# 2022-05-10 3
# 2022-05-11 4
# 2022-05-12 5
# 2022-05-13 5
# 2022-05-14 1
# 2022-05-15 1
# 2022-05-16 3
# 2022-05-17 4
# 2022-05-18 5
# 2022-05-19 3
# 2022-05-20 4
# 2022-05-21 3
# 2022-05-22 2
# 2022-05-23 3
# 2022-05-24 3
# 2022-05-25 1
# 2022-05-28 2
# 2022-05-29 1
# 2022-05-30 1
# 2022-05-31 2
# 2022-06-03 1
# 2022-06-04 2
# 2022-06-05 2
# 2022-06-07 3
# 2022-06-08 3
# 2022-06-09 5
# 2022-06-10 3
# 2022-06-11 1
# 2022-06-12 3
# 2022-06-13 2
# 2022-06-14 2
# 2022-06-15 2
# 2022-06-16 2
# 2022-06-17 2
# 2022-06-18 2
# 2022-06-19 2
# 2022-06-20 5
# 2022-06-21 5
# 2022-06-22 2
# 2022-06-23 3
# 2022-06-24 1
# 2022-06-25 1
# 2022-06-26 1
# 2022-06-27 3
# 2022-06-28 3
# 2022-06-29 3
# 2022-06-30 4
# 2022-07-01 5
# 2022-07-02 1
# 2022-07-03 1
# 2022-07-04 2
# 2022-07-05 2
# 2022-07-06 1
# 2022-07-07 2
# 2022-07-08 2
# 2022-07-09 2
# 2022-07-10 2
# 2022-07-11 2
# 2022-07-12 2
# 2022-07-13 3
# 2022-07-14 3
# 2022-07-15 3
# 2022-07-16 1
# 2022-07-17 2
# 2022-07-18 2
# 2022-07-19 1
# 2022-08-28 1
# 2022-08-29 1
# 2022-08-31 2
# 2022-09-01 2
# 2022-09-02 2
# 2022-09-03 2
# 2022-09-04 1
# 2022-09-05 2
# 2022-09-06 3
# 2022-09-07 4
# 2022-09-08 5
# 2022-09-09 4
# 2022-09-10 3
# 2022-09-11 5
# 2022-09-12 5
# 2022-09-13 3
# 2022-09-14 3
# 2022-09-15 3
# 2022-09-16 5
# 2022-09-17 3
# 2022-09-18 3
# 2022-09-19 3
# 2022-09-20 2
# 2022-09-21 4
# 2022-09-22 4
# 2022-09-23 1
# 2022-09-24 1
# 2022-09-25 1
# 2022-09-26 4
# 2022-09-27 5
# 2022-09-28 3
# 2022-09-29 3
# 2022-09-30 1
# 2022-10-01 1
# 2022-10-03 1
# 2022-10-04 2
# 2022-10-05 2
# 2022-10-06 3
# 2022-10-07 3
# 2022-10-08 3
# 2022-10-09 2
# 2022-10-10 2
# 2022-10-11 3
# 2022-10-12 3
# 2022-10-13 4
# 2022-10-14 5
# 2022-10-15 3
# 2022-10-16 3
# 2022-10-17 5
# 2022-10-18 3
# 2022-10-19 4
# 2022-10-20 2
# 2022-10-21 4
# 2022-10-22 3
# 2022-10-23 2
# 2022-10-24 6
# 2022-10-25 5
# 2022-10-26 2
# 2022-10-27 2
# 2022-10-28 2
# 2022-10-29 2
# 2022-10-30 1
# 2022-11-02 3
# 2022-11-03 3
# 2022-11-04 3
# 2022-11-05 1
# 2022-11-06 2
# 2022-11-07 4
# 2022-11-08 3
# 2022-11-09 3
# 2022-11-10 3
# 2022-11-11 1
# 2022-11-12 2
# 2022-11-13 1
# 2022-11-14 2
# 2022-11-15 2
# 2022-11-16 3
# 2022-11-17 3
# 2022-11-18 3
# 2022-11-19 2
# 2022-11-20 1
# 2022-11-21 4
# 2022-11-22 2
# 2022-11-23 3
# 2022-11-24 2
# 2022-11-25 3
# 2022-11-26 2
# 2022-11-27 2
# 2022-11-28 5
# 2022-11-29 7
# 2022-11-30 5
# 2022-12-01 3
# 2022-12-02 4
# 2022-12-03 2
# 2022-12-04 2
# 2022-12-05 1
# 2022-12-06 4
# 2022-12-07 7
# 2022-12-08 6
# 2022-12-09 5
# 2022-12-10 4
# 2022-12-11 3
# 2022-12-12 3
# 2022-12-13 6
# 2022-12-14 4
# 2022-12-15 2
# 2022-12-16 3
# 2022-12-17 4
# 2022-12-18 3
# 2022-12-19 7
# 2022-12-20 3
# 2022-12-21 3
# 2022-12-22 3
# 2022-12-23 1
# 2023-01-02 1
# 2023-01-03 1
# 2023-01-04 1
# 2023-01-05 1
# 2023-01-06 1
# 2023-01-07 1
# 2023-01-08 1
# 2023-01-09 3
# 2023-01-10 1
# 2023-01-11 2
# 2023-01-12 1
# 2023-01-14 1
# 2023-01-16 2
# 2023-01-17 2
# 2023-01-18 2
# 2023-01-19 3
# 2023-01-20 1
# 2023-01-24 1
# 2023-01-25 4
# 2023-01-26 1
# 2023-01-27 2
# 2023-01-28 4
# 2023-01-29 3
# 2023-01-30 1
# 2023-01-31 2
# 2023-02-01 3
# 2023-02-02 1
# 2023-02-03 1
# 2023-02-04 3
# 2023-02-05 3
# 2023-02-06 3
# 2023-02-07 2
# 2023-02-08 2
# 2023-02-09 2
# 2023-02-10 2
# 2023-02-11 1
# 2023-02-12 1
# 2023-02-13 2
# 2023-02-14 2
# 2023-02-15 2
# 2023-02-16 2
# 2023-02-17 2
# 2023-02-18 1
# 2023-02-19 1
# 2023-02-20 2
# 2023-02-21 2
# 2023-02-22 2
# 2023-02-23 2
# 2023-02-24 2
# 2023-02-25 2
# 2023-02-26 2
# 2023-02-27 2
# 2023-02-28 2
# 2023-03-01 2
# 2023-03-02 2
# 2023-03-03 2
# 2023-03-04 1
# 2023-03-05 1
# 2023-03-06 3
# 2023-03-07 2
# 2023-03-08 3
# 2023-03-09 3
# 2023-03-10 2
# 2023-03-11 1
# 2023-03-12 2
# 2023-03-13 4
# 2023-03-14 3
# 2023-03-15 3
# 2023-03-16 3
# 2023-03-17 3
# 2023-03-18 2
# 2023-03-19 1
# 2023-03-20 5
# 2023-03-21 4
# 2023-03-22 5
# 2023-03-23 5
# 2023-03-24 4
# 2023-03-25 2
# 2023-03-26 1
# 2023-03-27 4
# 2023-03-28 3
# 2023-03-29 4
# 2023-03-30 1
# 2023-03-31 2
# 2023-04-01 1
# 2023-04-02 2
# 2023-04-03 2
# 2023-04-04 5
# 2023-04-05 6
# 2023-04-06 3
# 2023-04-07 6
# 2023-04-08 3
# 2023-04-09 2
# 2023-04-11 2
# 2023-04-12 2
# 2023-04-13 4
# 2023-04-14 5
# 2023-04-15 3
# 2023-04-16 3
# 2023-04-17 4
# 2023-04-18 4
# 2023-04-19 3
# 2023-04-20 2
# 2023-04-21 4
# 2023-04-22 2
# 2023-04-23 1
# 2023-04-24 4
# 2023-04-25 4
# 2023-04-26 4
# 2023-04-27 3
# 2023-04-28 4
# 2023-04-29 1
# 2023-04-30 1
# 2023-05-02 2
# 2023-05-03 2
# 2023-05-04 2
# 2023-05-05 2
# 2023-05-06 2
# 2023-05-07 1
# 2023-05-09 2
# 2023-05-10 3
# 2023-05-11 3
# 2023-05-12 3
# 2023-05-13 2
# 2023-05-14 2
# 2023-05-15 3
# 2023-05-16 5
# 2023-05-17 3
# 2023-05-18 3
# 2023-05-19 3
# 2023-05-20 3
# 2023-05-21 2
# 2023-05-24 2
# 2023-05-25 2
# 2023-05-26 2
# 2023-05-27 2
# 2023-05-28 1
# 2023-05-30 5
# 2023-05-31 6
# 2023-06-01 6
# 2023-06-02 7
# 2023-06-03 8
# 2023-06-04 5
# 2023-06-05 10
# 2023-06-06 5
# 2023-06-07 12
# 2023-06-08 6
# 2023-06-09 8
# 2023-06-10 5
# 2023-06-11 2
# 2023-06-12 4
# 2023-06-13 10
# 2023-06-14 10
# 2023-06-15 5
# 2023-06-16 4
# 2023-06-17 4
# 2023-06-18 2
# 2023-06-19 7
# 2023-06-20 10
# 2023-06-21 6
# 2023-06-22 6
# 2023-06-23 9
# 2023-06-24 6
# 2023-06-25 3
# 2023-06-26 7
# 2023-06-27 8
# 2023-06-28 9
# 2023-06-29 7
# 2023-06-30 8
# 2023-07-01 5
# 2023-07-02 4
# 2023-07-03 10
# 2023-07-04 9
# 2023-07-05 10
# 2023-07-06 8
# 2023-07-07 11
# 2023-07-08 6
# 2023-07-09 3
# 2023-07-10 5
# 2023-07-11 4
# 2023-07-12 3
# 2023-07-13 3
# 2023-07-14 3
# 2023-07-17 1
# 2023-07-18 1
# 2023-07-19 1
# 2023-07-20 1
# 2023-07-21 1
# 2023-07-24 3
# 2023-07-25 3
# 2023-07-26 2
# 2023-07-27 2
# 2023-07-28 1
# 2023-08-22 2
# 2023-08-28 2
# 2023-08-29 7
# 2023-08-30 9
# 2023-08-31 7
# 2023-09-01 7
# 2023-09-02 3
# 2023-09-03 4
# 2023-09-04 5
# 2023-09-05 8
# 2023-09-06 9
# 2023-09-07 6
# 2023-09-08 7
# 2023-09-09 4
# 2023-09-10 3
# 2023-09-11 4
# 2023-09-12 7
# 2023-09-13 4
# 2023-09-14 4
# 2023-09-15 6
# 2023-09-16 4
# 2023-09-17 3
# 2023-09-18 4
# 2023-09-19 5
# 2023-09-20 3
# 2023-09-21 3
# 2023-09-22 4
# 2023-09-23 5
# 2023-09-24 7
# 2023-09-25 5
# 2023-09-26 5
# 2023-09-27 5
# 2023-09-28 4
# 2023-09-29 3
# 2023-09-30 6
# 2023-10-01 7
# 2023-10-02 10
# 2023-10-03 4
# 2023-10-04 5
# 2023-10-05 5
# 2023-10-06 6
# 2023-10-07 5
# 2023-10-08 6
# 2023-10-09 6
# 2023-10-10 5
# 2023-10-11 4
# 2023-10-12 7
# 2023-10-13 6
# 2023-10-14 2
# 2023-10-15 6
# 2023-10-16 8
# 2023-10-17 4
# 2023-10-18 4
# 2023-10-19 6
# 2023-10-20 5
# 2023-10-21 3
# 2023-10-22 3
# 2023-10-23 9
# 2023-10-24 5
# 2023-10-25 5
# 2023-10-26 5
# 2023-10-27 3
# 2023-10-28 1
# 2023-10-29 1
# 2023-10-30 1
# 2023-10-31 1
# 2023-11-02 5
# 2023-11-03 4
# 2023-11-04 3
# 2023-11-05 1
# 2023-11-06 6
# 2023-11-07 6
# 2023-11-08 7
# 2023-11-09 6
# 2023-11-10 6
# 2023-11-11 3
# 2023-11-12 2
# 2023-11-13 5
# 2023-11-14 4
# 2023-11-15 3
# 2023-11-16 5
# 2023-11-17 6
# 2023-11-18 4
# 2023-11-19 1
# 2023-11-20 2
# 2023-11-21 2
# 2023-11-22 2
# 2023-11-23 2
# 2023-11-24 2
# 2023-11-25 4
# 2023-11-26 4
# 2023-11-27 10
# 2023-11-28 7
# 2023-11-29 5
# 2023-11-30 6
# 2023-12-01 2
# 2023-12-02 4
# 2023-12-03 4
# 2023-12-04 4
# 2023-12-05 5
# 2023-12-06 5
# 2023-12-07 2
# 2023-12-08 5
# 2023-12-09 4
# 2023-12-10 4
# 2023-12-11 7
# 2023-12-12 5
# 2023-12-13 4
# 2023-12-14 4
# 2023-12-15 3
# 2023-12-16 2
# 2023-12-17 2
# 2023-12-18 3
# 2023-12-19 2
# 2023-12-20 2
# 2024-01-10 1
# 2024-01-11 1
# 2024-01-14 1
# 2024-01-15 1
# 2024-01-16 1
# 2024-01-17 1
# 2024-01-18 1
# 2024-01-19 1
# 2024-01-22 2
# 2024-01-23 3
# 2024-01-24 3
# 2024-01-25 2
# 2024-01-26 3
# 2024-01-27 1
# 2024-01-28 2
# 2024-01-29 4
# 2024-01-30 5
# 2024-01-31 5
# 2024-02-01 6
# 2024-02-02 5
# 2024-02-03 2
# 2024-02-04 2
# 2024-02-05 3
# 2024-02-06 3
# 2024-02-07 3
# 2024-02-08 3
# 2024-02-09 2
# 2024-02-11 1
# 2024-02-12 5
# 2024-02-13 3
# 2024-02-14 2
# 2024-02-15 1
# 2024-02-19 2
# 2024-02-20 3
# 2024-02-21 4
# 2024-02-22 4
# 2024-02-23 3
# 2024-02-24 2
# 2024-02-25 2
# 2024-02-26 5
# 2024-02-27 5
# 2024-02-28 6
# 2024-02-29 3
# 2024-03-01 5
# 2024-03-02 2
# 2024-03-03 2
# 2024-03-04 4
# 2024-03-05 5
# 2024-03-06 6
# 2024-03-07 5
# 2024-03-08 5
# 2024-03-09 3
# 2024-03-10 1
# 2024-03-11 5
# 2024-03-12 7
# 2024-03-13 5
# 2024-03-14 4
# 2024-03-15 2
# 2024-03-16 4
# 2024-03-17 2
# 2024-03-18 7
# 2024-03-19 8
# 2024-03-20 6
# 2024-03-21 5
# 2024-03-22 4
# 2024-03-23 6
# 2024-03-24 6
# 2024-03-25 7
# 2024-03-26 3
# 2024-03-27 3
# 2024-03-28 3
# 2024-03-29 4
# 2024-03-30 6
# 2024-03-31 4
# 2024-04-01 1
# 2024-04-02 6
# 2024-04-03 6
# 2024-04-04 7
# 2024-04-05 1
# 2024-04-06 1
# 2024-04-07 1
# 2024-04-08 2
# 2024-04-09 2
# 2024-04-10 5
# 2024-04-11 6
# 2024-04-12 2
# 2024-04-13 3
# 2024-04-14 3
# 2024-04-15 6
# 2024-04-16 4
# 2024-04-17 6
# 2024-04-18 4
# 2024-04-19 4
# 2024-04-20 1
# 2024-04-21 2
# 2024-04-22 5
# 2024-04-23 3
# 2024-04-24 4
# 2024-04-25 3
# 2024-04-26 4
# 2024-04-27 3
# 2024-04-28 1
# 2024-04-29 4
# 2024-04-30 4
# 2024-05-01 1
# 2024-05-02 1
# 2024-05-03 1
# 2024-05-04 1
# 2024-05-05 1
# 2024-05-06 1
# 2024-05-11 5
# 2024-05-12 5
# 2024-05-13 6
# 2024-05-14 2
# 2024-05-15 4
# 2024-05-16 3
# 2024-05-17 3
# 2024-05-18 2
# 2024-05-19 3
# 2024-05-20 2
# 2024-05-21 8
# 2024-05-22 6
# 2024-05-23 3
# 2024-05-24 4
# 2024-05-25 2
# 2024-05-26 3
# 2024-05-27 5
# 2024-05-28 2
# 2024-05-29 4
# 2024-05-30 4
# 2024-05-31 1
# 2024-06-01 1
# 2024-06-02 3
# 2024-06-03 8
# 2024-06-04 5
# 2024-06-05 6
# 2024-06-06 5
# 2024-06-07 4
# 2024-06-08 4
# 2024-06-09 4
# 2024-06-10 7
# 2024-06-11 4
# 2024-06-12 5
# 2024-06-13 5
# 2024-06-14 4
# 2024-06-15 5
# 2024-06-16 2
# 2024-06-17 6
# 2024-06-18 6
# 2024-06-19 7
# 2024-06-20 8
# 2024-06-21 8
# 2024-06-22 5
# 2024-06-23 6
# 2024-06-24 5
# 2024-06-25 6
# 2024-06-26 7
# 2024-06-27 8
# 2024-06-28 6
# 2024-06-29 7
# 2024-06-30 7
# 2024-07-01 6
# 2024-07-02 6
# 2024-07-03 10
# 2024-07-04 7
# 2024-07-05 5
# 2024-07-06 1
# 2024-07-07 2
# 2024-07-08 6
# 2024-07-09 8
# 2024-07-10 7
# 2024-07-11 6
# 2024-07-12 4
# 2024-07-13 3
# 2024-07-14 1
# 2024-07-15 3
# 2024-07-17 1
# 2024-07-18 3
# 2024-07-21 2
# 2024-07-22 1
# 2024-07-23 1
# 2024-07-24 1
# 2024-07-26 1
# 2024-07-28 1
# 2024-07-29 3
# 2024-07-30 1
# 2024-07-31 1
# 2024-08-01 1
# 2024-08-02 2
# 2024-08-03 1
# 2024-08-05 2
# 2024-08-06 1
# 2024-08-10 1
# 2024-08-17 4
# 2024-08-18 5
# 2024-08-19 8
# 2024-08-20 4
# 2024-08-21 5
# 2024-08-22 5
# 2024-08-23 2
# 2024-08-24 1
# 2024-08-26 3
# 2024-08-27 1
# 2024-08-28 3
# 2024-08-29 2
# 2024-08-30 1
# 2024-09-01 1
# 2024-09-02 1
# 2024-09-03 2
# 2024-09-04 2
# 2024-09-09 1
# 2024-09-10 2
# 2024-09-11 2
# 2024-09-12 2
# 2024-09-13 2
# 2024-09-14 2
# 2024-10-04 3
# 2024-10-05 3
# 2024-10-06 2
# 2024-10-07 2
# 2024-10-21 3
# 2024-10-22 4
# 2024-10-23 1
# 2024-10-24 1
# 2024-10-27 2
# 2024-10-28 3
# 2024-10-29 1
# 2024-10-30 1
# 2024-10-31 1
# 2024-11-01 1
# 2024-11-02 1
# 2024-11-03 2
# 2024-11-04 2
# 2024-11-05 3
# 2024-11-06 4
# 2024-11-07 2
# 2024-11-08 5
# 2024-11-09 3
# 2024-11-10 2
# 2024-11-11 3
# 2024-11-12 3
# 2024-11-13 2
# 2024-11-14 2
# 2024-11-15 1
# 2024-11-16 1
# 2024-11-17 1
# 2024-11-22 2
# 2024-11-23 4
# 2024-11-24 1
# 2024-11-25 2
# 2024-11-26 2
# 2024-11-27 1
# 2024-12-10 1
# 2024-12-11 1
# 2024-12-12 1
# 2025-01-06 3
# 2025-01-07 4
# 2025-01-08 2
# 2025-01-09 3
# 2025-01-10 2
# 2025-01-11 2
# 2025-01-12 4
# 2025-01-13 2
# 2025-01-20 3
# 2025-01-21 4
# 2025-01-22 1
# 2025-01-23 3
# 2025-01-24 2
# 2025-01-25 2
# 2025-01-26 4
# 2025-01-27 5
# 2025-01-28 3
# 2025-01-29 2
# 2025-01-30 3
# 2025-01-31 2
# 2025-02-01 4
# 2025-02-02 4
# 2025-02-04 2
# 2025-02-05 2
# 2025-02-06 1
# 2025-02-07 1
# 2025-02-24 1
# 2025-02-25 1
# 2025-02-26 2
# 2025-02-27 2
# 2025-02-28 1
# 2025-03-05 3
# 2025-03-06 5
# 2025-03-07 5
# 2025-03-08 4
# 2025-03-09 5
# 2025-03-10 4
# 2025-03-11 4
# 2025-03-12 1
# 2025-03-13 1
# 2025-03-14 1
# 2026-01-05 3
# 2026-01-06 3
# 2026-01-07 2
# 2026-01-08 2
# 2026-01-13 3
# 2026-01-14 4
# 2026-01-15 2
# 2026-01-16 2
# 2026-01-17 1
# 2026-01-22 3
# 2026-01-23 3
# 2026-01-24 2
# 2026-01-25 2
# 2026-01-26 2
# 2026-01-27 2
# 2026-01-28 2
# 2026-01-29 1
# 2026-01-30 1
# 2026-01-31 1
# 2026-02-01 1
# 2026-02-02 1
# 2026-02-06 3
# 2026-02-07 3
# 2026-02-08 2
# 2026-02-09 2
# 2026-02-10 2
# 2026-02-11 2
# 2026-02-16 3
# 2026-02-17 3
# 2026-02-18 2
# 2026-02-19 2
# 2026-02-20 2
# 2026-02-21 2
# 2026-02-22 1
# 2026-02-26 3
# 2026-02-27 3
# 2026-02-28 2
# 2026-03-01 2
# 2026-03-02 2
# 2026-03-03 2
# 2026-03-04 1
# 2026-03-08 3
# 2026-03-09 3
# 2026-03-10 1
# 2026-03-11 1
# 2026-03-12 1
# 2026-03-13 1
# 2026-03-14 1
# 2026-03-23 3
# 2026-03-24 3
# 2026-03-25 1
# 2026-03-26 1
# 2026-03-27 1
# 2026-03-28 1
# 2026-04-02 3
# 2026-04-03 3
# 2026-04-04 1
# 2026-04-05 1
# 2026-04-06 1
# 2026-04-07 1
# 2026-04-12 3
# 2026-04-13 3
# 2026-04-14 1
# 2026-04-15 1
# 2026-04-16 1
# 2026-04-17 1
# 2026-04-18 1
# 2026-04-19 1
# 2026-04-20 1
# 2026-04-21 1
# 2026-04-25 3
# 2026-04-26 3
# 2026-04-27 1
# 2026-04-28 1
# 2026-04-29 1
# 2026-04-30 1
# 2026-05-01 1
# 2026-05-02 1
# 2026-05-03 1
# 2026-05-07 2
# 2026-05-08 3
# 2026-05-09 1
# 2026-05-10 2
# 2026-05-11 2
# 2026-05-12 1
# 2026-05-13 1
# 2026-05-14 1
# 2026-05-15 1
# 2026-05-20 3
# 2026-05-21 4
# 2026-05-22 1
# 2026-05-23 1
# 2026-05-24 1
# 2026-05-25 1
# 2026-05-26 1
# 2026-05-27 1
# 2026-05-28 1
# 2026-06-22 3
# 2026-06-23 3
# 2026-06-24 2
# 2026-06-25 2

# %%
# Example usage
scope_id   = 26
start_date = datetime(2024, 11, 25, 0, 0)
end_date   = datetime(2024, 11, 26, 0, 0)

data = gather_all_scheduling_data(scope_id, start_date, end_date, max_tasks=10)

print("Retrieved data keys:", data.keys())

print("\n=== PROCESSES ===")
for row in data["processes"][:30]:
    print(row)

print("\n=== EQUIPMENT ===")
for eq in data["equipment"]:
    print(eq)

print("\n=== WORKERS ===")
for wid, winfo in data["workers"].items():
    print(wid, winfo)
    
print("\n=== ZONES ===")
for zone in data["zones"]:
    print(zone)

print("\n=== SHIFTS ===")
for wid, shift_list in data["shifts"].items():
    print(f"Worker {wid} has shifts:")
    for sh in shift_list:
        print(" ", sh)
# Out:
# Retrieved data keys: dict_keys(['processes', 'equipment', 'zones', 'workers', 'shifts'])
#
# === PROCESSES ===
# {'process_id': 201, 'process_name': '53DF87F3-1A1A-494B-B412-3F265C8EF409', 'act_id': 520, 'act_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6', 'act_category': '02B6E7CE-EFE9-4C3B-9257-C5AE03ECD205', 'act_workload': 600, 'defaultStatus': 'assigned', 'workCadence': None, 'workersPerBox': None, 'prefweekend': 0, 'block_zone': 'Y', 'pra_seq': 1, 'pra_groupnum': None, 'pra_interval': None, 'pra_max_interval': None, 'pra_start_interval': None, 'pra_workload': None, 'PRA_PARA_ALIGN': None, 'requiredWorkers': '[{"ACR_QTY":5,"RE_NAME":"opérateur","RE_TYPE":"TEAM"}]', 'resource_type': 'TEAM', 'resource_name': 'opérateur', 'resource_id': 925, 'equipment_category': 'UNDEFINED', 'resource_quantity': 5, 'resource_option': 'auto', 'equip_workload': 0, 'start_date': datetime.datetime(2024, 11, 25, 1, 20), 'end_date': datetime.datetime(2024, 11, 25, 22, 0)}
# {'process_id': 201, 'process_name': '53DF87F3-1A1A-494B-B412-3F265C8EF409', 'act_id': 520, 'act_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6', 'act_category': '02B6E7CE-EFE9-4C3B-9257-C5AE03ECD205', 'act_workload': 600, 'defaultStatus': 'assigned', 'workCadence': None, 'workersPerBox': None, 'prefweekend': 0, 'block_zone': 'Y', 'pra_seq': 1, 'pra_groupnum': None, 'pra_interval': None, 'pra_max_interval': None, 'pra_start_interval': None, 'pra_workload': None, 'PRA_PARA_ALIGN': None, 'requiredWorkers': '[{"ACR_QTY":5,"RE_NAME":"opérateur","RE_TYPE":"TEAM"}]', 'resource_type': 'EQUIPEMENT', 'resource_name': 'L1 - 02 - Isolateur SKAN', 'resource_id': 933, 'equipment_category': 'UNDEFINED', 'resource_quantity': 0, 'resource_option': 'required', 'equip_workload': None, 'start_date': datetime.datetime(2024, 11, 25, 1, 20), 'end_date': datetime.datetime(2024, 11, 25, 22, 0)}
# {'process_id': 201, 'process_name': '53DF87F3-1A1A-494B-B412-3F265C8EF409', 'act_id': 520, 'act_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6', 'act_category': '02B6E7CE-EFE9-4C3B-9257-C5AE03ECD205', 'act_workload': 600, 'defaultStatus': 'assigned', 'workCadence': None, 'workersPerBox': None, 'prefweekend': 0, 'block_zone': 'Y', 'pra_seq': 1, 'pra_groupnum': None, 'pra_interval': None, 'pra_max_interval': None, 'pra_start_interval': None, 'pra_workload': None, 'PRA_PARA_ALIGN': None, 'requiredWorkers': '[{"ACR_QTY":5,"RE_NAME":"opérateur","RE_TYPE":"TEAM"}]', 'resource_type': 'EQUIPEMENT', 'resource_name': 'L1 - 03 - LYO A', 'resource_id': 934, 'equipment_category': 'UNDEFINED', 'resource_quantity': 0, 'resource_option': 'auto', 'equip_workload': None, 'start_date': datetime.datetime(2024, 11, 25, 1, 20), 'end_date': datetime.datetime(2024, 11, 25, 22, 0)}
# {'process_id': 201, 'process_name': '53DF87F3-1A1A-494B-B412-3F265C8EF409', 'act_id': 520, 'act_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6', 'act_category': '02B6E7CE-EFE9-4C3B-9257-C5AE03ECD205', 'act_workload': 600, 'defaultStatus': 'assigned', 'workCadence': None, 'workersPerBox': None, 'prefweekend': 0, 'block_zone': 'Y', 'pra_seq': 1, 'pra_groupnum': None, 'pra_interval': None, 'pra_max_interval': None, 'pra_start_interval': None, 'pra_workload': None, 'PRA_PARA_ALIGN': None, 'requiredWorkers': '[{"ACR_QTY":5,"RE_NAME":"opérateur","RE_TYPE":"TEAM"}]', 'resource_type': 'EQUIPEMENT', 'resource_name': 'L1 - 04 - LYO B', 'resource_id': 935, 'equipment_category': 'UNDEFINED', 'resource_quantity': 0, 'resource_option': 'auto', 'equip_workload': None, 'start_date': datetime.datetime(2024, 11, 25, 1, 20), 'end_date': datetime.datetime(2024, 11, 25, 22, 0)}
# {'process_id': 201, 'process_name': '53DF87F3-1A1A-494B-B412-3F265C8EF409', 'act_id': 520, 'act_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6', 'act_category': '02B6E7CE-EFE9-4C3B-9257-C5AE03ECD205', 'act_workload': 600, 'defaultStatus': 'assigned', 'workCadence': None, 'workersPerBox': None, 'prefweekend': 0, 'block_zone': 'Y', 'pra_seq': 1, 'pra_groupnum': None, 'pra_interval': None, 'pra_max_interval': None, 'pra_start_interval': None, 'pra_workload': None, 'PRA_PARA_ALIGN': None, 'requiredWorkers': '[{"ACR_QTY":5,"RE_NAME":"opérateur","RE_TYPE":"TEAM"}]', 'resource_type': 'EQUIPEMENT', 'resource_name': 'L1 - 05 - LYO C', 'resource_id': 936, 'equipment_category': 'UNDEFINED', 'resource_quantity': 0, 'resource_option': 'auto', 'equip_workload': None, 'start_date': datetime.datetime(2024, 11, 25, 1, 20), 'end_date': datetime.datetime(2024, 11, 25, 22, 0)}
# {'process_id': 201, 'process_name': '53DF87F3-1A1A-494B-B412-3F265C8EF409', 'act_id': 520, 'act_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6', 'act_category': '02B6E7CE-EFE9-4C3B-9257-C5AE03ECD205', 'act_workload': 600, 'defaultStatus': 'assigned', 'workCadence': None, 'workersPerBox': None, 'prefweekend': 0, 'block_zone': 'Y', 'pra_seq': 1, 'pra_groupnum': None, 'pra_interval': None, 'pra_max_interval': None, 'pra_start_interval': None, 'pra_workload': None, 'PRA_PARA_ALIGN': None, 'requiredWorkers': '[{"ACR_QTY":5,"RE_NAME":"opérateur","RE_TYPE":"TEAM"}]', 'resource_type': 'EQUIPEMENT', 'resource_name': 'L1 - 06 -  LYO D', 'resource_id': 937, 'equipment_category': 'UNDEFINED', 'resource_quantity': 0, 'resource_option': 'auto', 'equip_workload': None, 'start_date': datetime.datetime(2024, 11, 25, 1, 20), 'end_date': datetime.datetime(2024, 11, 25, 22, 0)}
# {'process_id': 201, 'process_name': '53DF87F3-1A1A-494B-B412-3F265C8EF409', 'act_id': 520, 'act_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6', 'act_category': '02B6E7CE-EFE9-4C3B-9257-C5AE03ECD205', 'act_workload': 600, 'defaultStatus': 'assigned', 'workCadence': None, 'workersPerBox': None, 'prefweekend': 0, 'block_zone': 'Y', 'pra_seq': 1, 'pra_groupnum': None, 'pra_interval': None, 'pra_max_interval': None, 'pra_start_interval': None, 'pra_workload': None, 'PRA_PARA_ALIGN': None, 'requiredWorkers': '[{"ACR_QTY":5,"RE_NAME":"opérateur","RE_TYPE":"TEAM"}]', 'resource_type': 'ZONE', 'resource_name': 'Ligne 1 - Chargement', 'resource_id': 926, 'equipment_category': 'UNDEFINED', 'resource_quantity': 0, 'resource_option': 'auto', 'equip_workload': None, 'start_date': datetime.datetime(2024, 11, 25, 1, 20), 'end_date': datetime.datetime(2024, 11, 25, 22, 0)}
# {'process_id': 201, 'process_name': '53DF87F3-1A1A-494B-B412-3F265C8EF409', 'act_id': 520, 'act_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6', 'act_category': '02B6E7CE-EFE9-4C3B-9257-C5AE03ECD205', 'act_workload': 600, 'defaultStatus': 'assigned', 'workCadence': None, 'workersPerBox': None, 'prefweekend': 0, 'block_zone': 'Y', 'pra_seq': 1, 'pra_groupnum': None, 'pra_interval': None, 'pra_max_interval': None, 'pra_start_interval': None, 'pra_workload': None, 'PRA_PARA_ALIGN': None, 'requiredWorkers': '[{"ACR_QTY":5,"RE_NAME":"opérateur","RE_TYPE":"TEAM"}]', 'resource_type': 'EQUIPEMENT', 'resource_name': 'L1 - 01 - Isolateur Bosch', 'resource_id': 932, 'equipment_category': 'UNDEFINED', 'resource_quantity': 0, 'resource_option': 'required', 'equip_workload': 600, 'start_date': datetime.datetime(2024, 11, 25, 1, 20), 'end_date': datetime.datetime(2024, 11, 25, 22, 0)}
# {'process_id': 201, 'process_name': '53DF87F3-1A1A-494B-B412-3F265C8EF409', 'act_id': 520, 'act_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6', 'act_category': '02B6E7CE-EFE9-4C3B-9257-C5AE03ECD205', 'act_workload': 600, 'defaultStatus': 'assigned', 'workCadence': None, 'workersPerBox': None, 'prefweekend': 0, 'block_zone': 'Y', 'pra_seq': 1, 'pra_groupnum': None, 'pra_interval': None, 'pra_max_interval': None, 'pra_start_interval': None, 'pra_workload': None, 'PRA_PARA_ALIGN': None, 'requiredWorkers': '[{"ACR_QTY":5,"RE_NAME":"opérateur","RE_TYPE":"TEAM"}]', 'resource_type': 'TEAM', 'resource_name': 'opérateur', 'resource_id': 925, 'equipment_category': 'UNDEFINED', 'resource_quantity': 5, 'resource_option': 'auto', 'equip_workload': 0, 'start_date': datetime.datetime(2024, 11, 25, 1, 20), 'end_date': datetime.datetime(2024, 11, 25, 22, 0)}
# {'process_id': 201, 'process_name': '53DF87F3-1A1A-494B-B412-3F265C8EF409', 'act_id': 520, 'act_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6', 'act_category': '02B6E7CE-EFE9-4C3B-9257-C5AE03ECD205', 'act_workload': 600, 'defaultStatus': 'assigned', 'workCadence': None, 'workersPerBox': None, 'prefweekend': 0, 'block_zone': 'Y', 'pra_seq': 1, 'pra_groupnum': None, 'pra_interval': None, 'pra_max_interval': None, 'pra_start_interval': None, 'pra_workload': None, 'PRA_PARA_ALIGN': None, 'requiredWorkers': '[{"ACR_QTY":5,"RE_NAME":"opérateur","RE_TYPE":"TEAM"}]', 'resource_type': 'EQUIPEMENT', 'resource_name': 'L1 - 02 - Isolateur SKAN', 'resource_id': 933, 'equipment_category': 'UNDEFINED', 'resource_quantity': 0, 'resource_option': 'required', 'equip_workload': None, 'start_date': datetime.datetime(2024, 11, 25, 1, 20), 'end_date': datetime.datetime(2024, 11, 25, 22, 0)}
# {'process_id': 201, 'process_name': '53DF87F3-1A1A-494B-B412-3F265C8EF409', 'act_id': 520, 'act_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6', 'act_category': '02B6E7CE-EFE9-4C3B-9257-C5AE03ECD205', 'act_workload': 600, 'defaultStatus': 'assigned', 'workCadence': None, 'workersPerBox': None, 'prefweekend': 0, 'block_zone': 'Y', 'pra_seq': 1, 'pra_groupnum': None, 'pra_interval': None, 'pra_max_interval': None, 'pra_start_interval': None, 'pra_workload': None, 'PRA_PARA_ALIGN': None, 'requiredWorkers': '[{"ACR_QTY":5,"RE_NAME":"opérateur","RE_TYPE":"TEAM"}]', 'resource_type': 'EQUIPEMENT', 'resource_name': 'L1 - 03 - LYO A', 'resource_id': 934, 'equipment_category': 'UNDEFINED', 'resource_quantity': 0, 'resource_option': 'auto', 'equip_workload': None, 'start_date': datetime.datetime(2024, 11, 25, 1, 20), 'end_date': datetime.datetime(2024, 11, 25, 22, 0)}
# {'process_id': 201, 'process_name': '53DF87F3-1A1A-494B-B412-3F265C8EF409', 'act_id': 520, 'act_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6', 'act_category': '02B6E7CE-EFE9-4C3B-9257-C5AE03ECD205', 'act_workload': 600, 'defaultStatus': 'assigned', 'workCadence': None, 'workersPerBox': None, 'prefweekend': 0, 'block_zone': 'Y', 'pra_seq': 1, 'pra_groupnum': None, 'pra_interval': None, 'pra_max_interval': None, 'pra_start_interval': None, 'pra_workload': None, 'PRA_PARA_ALIGN': None, 'requiredWorkers': '[{"ACR_QTY":5,"RE_NAME":"opérateur","RE_TYPE":"TEAM"}]', 'resource_type': 'EQUIPEMENT', 'resource_name': 'L1 - 04 - LYO B', 'resource_id': 935, 'equipment_category': 'UNDEFINED', 'resource_quantity': 0, 'resource_option': 'auto', 'equip_workload': None, 'start_date': datetime.datetime(2024, 11, 25, 1, 20), 'end_date': datetime.datetime(2024, 11, 25, 22, 0)}
# {'process_id': 201, 'process_name': '53DF87F3-1A1A-494B-B412-3F265C8EF409', 'act_id': 520, 'act_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6', 'act_category': '02B6E7CE-EFE9-4C3B-9257-C5AE03ECD205', 'act_workload': 600, 'defaultStatus': 'assigned', 'workCadence': None, 'workersPerBox': None, 'prefweekend': 0, 'block_zone': 'Y', 'pra_seq': 1, 'pra_groupnum': None, 'pra_interval': None, 'pra_max_interval': None, 'pra_start_interval': None, 'pra_workload': None, 'PRA_PARA_ALIGN': None, 'requiredWorkers': '[{"ACR_QTY":5,"RE_NAME":"opérateur","RE_TYPE":"TEAM"}]', 'resource_type': 'EQUIPEMENT', 'resource_name': 'L1 - 05 - LYO C', 'resource_id': 936, 'equipment_category': 'UNDEFINED', 'resource_quantity': 0, 'resource_option': 'auto', 'equip_workload': None, 'start_date': datetime.datetime(2024, 11, 25, 1, 20), 'end_date': datetime.datetime(2024, 11, 25, 22, 0)}
# {'process_id': 201, 'process_name': '53DF87F3-1A1A-494B-B412-3F265C8EF409', 'act_id': 520, 'act_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6', 'act_category': '02B6E7CE-EFE9-4C3B-9257-C5AE03ECD205', 'act_workload': 600, 'defaultStatus': 'assigned', 'workCadence': None, 'workersPerBox': None, 'prefweekend': 0, 'block_zone': 'Y', 'pra_seq': 1, 'pra_groupnum': None, 'pra_interval': None, 'pra_max_interval': None, 'pra_start_interval': None, 'pra_workload': None, 'PRA_PARA_ALIGN': None, 'requiredWorkers': '[{"ACR_QTY":5,"RE_NAME":"opérateur","RE_TYPE":"TEAM"}]', 'resource_type': 'EQUIPEMENT', 'resource_name': 'L1 - 06 -  LYO D', 'resource_id': 937, 'equipment_category': 'UNDEFINED', 'resource_quantity': 0, 'resource_option': 'auto', 'equip_workload': None, 'start_date': datetime.datetime(2024, 11, 25, 1, 20), 'end_date': datetime.datetime(2024, 11, 25, 22, 0)}
# {'process_id': 201, 'process_name': '53DF87F3-1A1A-494B-B412-3F265C8EF409', 'act_id': 520, 'act_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6', 'act_category': '02B6E7CE-EFE9-4C3B-9257-C5AE03ECD205', 'act_workload': 600, 'defaultStatus': 'assigned', 'workCadence': None, 'workersPerBox': None, 'prefweekend': 0, 'block_zone': 'Y', 'pra_seq': 1, 'pra_groupnum': None, 'pra_interval': None, 'pra_max_interval': None, 'pra_start_interval': None, 'pra_workload': None, 'PRA_PARA_ALIGN': None, 'requiredWorkers': '[{"ACR_QTY":5,"RE_NAME":"opérateur","RE_TYPE":"TEAM"}]', 'resource_type': 'ZONE', 'resource_name': 'Ligne 1 - Chargement', 'resource_id': 926, 'equipment_category': 'UNDEFINED', 'resource_quantity': 0, 'resource_option': 'auto', 'equip_workload': None, 'start_date': datetime.datetime(2024, 11, 25, 1, 20), 'end_date': datetime.datetime(2024, 11, 25, 22, 0)}
# {'process_id': 201, 'process_name': '53DF87F3-1A1A-494B-B412-3F265C8EF409', 'act_id': 520, 'act_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6', 'act_category': '02B6E7CE-EFE9-4C3B-9257-C5AE03ECD205', 'act_workload': 600, 'defaultStatus': 'assigned', 'workCadence': None, 'workersPerBox': None, 'prefweekend': 0, 'block_zone': 'Y', 'pra_seq': 1, 'pra_groupnum': None, 'pra_interval': None, 'pra_max_interval': None, 'pra_start_interval': None, 'pra_workload': None, 'PRA_PARA_ALIGN': None, 'requiredWorkers': '[{"ACR_QTY":5,"RE_NAME":"opérateur","RE_TYPE":"TEAM"}]', 'resource_type': 'EQUIPEMENT', 'resource_name': 'L1 - 01 - Isolateur Bosch', 'resource_id': 932, 'equipment_category': 'UNDEFINED', 'resource_quantity': 0, 'resource_option': 'required', 'equip_workload': 600, 'start_date': datetime.datetime(2024, 11, 25, 1, 20), 'end_date': datetime.datetime(2024, 11, 25, 22, 0)}
# {'process_id': 201, 'process_name': '53DF87F3-1A1A-494B-B412-3F265C8EF409', 'act_id': 520, 'act_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6', 'act_category': '02B6E7CE-EFE9-4C3B-9257-C5AE03ECD205', 'act_workload': 600, 'defaultStatus': 'assigned', 'workCadence': None, 'workersPerBox': None, 'prefweekend': 0, 'block_zone': 'Y', 'pra_seq': 1, 'pra_groupnum': None, 'pra_interval': None, 'pra_max_interval': None, 'pra_start_interval': None, 'pra_workload': None, 'PRA_PARA_ALIGN': None, 'requiredWorkers': '[{"ACR_QTY":5,"RE_NAME":"opérateur","RE_TYPE":"TEAM"}]', 'resource_type': 'TEAM', 'resource_name': 'opérateur', 'resource_id': 925, 'equipment_category': 'UNDEFINED', 'resource_quantity': 5, 'resource_option': 'auto', 'equip_workload': 0, 'start_date': datetime.datetime(2024, 11, 25, 1, 20), 'end_date': datetime.datetime(2024, 11, 25, 22, 0)}
# {'process_id': 201, 'process_name': '53DF87F3-1A1A-494B-B412-3F265C8EF409', 'act_id': 520, 'act_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6', 'act_category': '02B6E7CE-EFE9-4C3B-9257-C5AE03ECD205', 'act_workload': 600, 'defaultStatus': 'assigned', 'workCadence': None, 'workersPerBox': None, 'prefweekend': 0, 'block_zone': 'Y', 'pra_seq': 1, 'pra_groupnum': None, 'pra_interval': None, 'pra_max_interval': None, 'pra_start_interval': None, 'pra_workload': None, 'PRA_PARA_ALIGN': None, 'requiredWorkers': '[{"ACR_QTY":5,"RE_NAME":"opérateur","RE_TYPE":"TEAM"}]', 'resource_type': 'EQUIPEMENT', 'resource_name': 'L1 - 02 - Isolateur SKAN', 'resource_id': 933, 'equipment_category': 'UNDEFINED', 'resource_quantity': 0, 'resource_option': 'required', 'equip_workload': None, 'start_date': datetime.datetime(2024, 11, 25, 1, 20), 'end_date': datetime.datetime(2024, 11, 25, 22, 0)}
# {'process_id': 201, 'process_name': '53DF87F3-1A1A-494B-B412-3F265C8EF409', 'act_id': 520, 'act_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6', 'act_category': '02B6E7CE-EFE9-4C3B-9257-C5AE03ECD205', 'act_workload': 600, 'defaultStatus': 'assigned', 'workCadence': None, 'workersPerBox': None, 'prefweekend': 0, 'block_zone': 'Y', 'pra_seq': 1, 'pra_groupnum': None, 'pra_interval': None, 'pra_max_interval': None, 'pra_start_interval': None, 'pra_workload': None, 'PRA_PARA_ALIGN': None, 'requiredWorkers': '[{"ACR_QTY":5,"RE_NAME":"opérateur","RE_TYPE":"TEAM"}]', 'resource_type': 'EQUIPEMENT', 'resource_name': 'L1 - 03 - LYO A', 'resource_id': 934, 'equipment_category': 'UNDEFINED', 'resource_quantity': 0, 'resource_option': 'auto', 'equip_workload': None, 'start_date': datetime.datetime(2024, 11, 25, 1, 20), 'end_date': datetime.datetime(2024, 11, 25, 22, 0)}
# {'process_id': 201, 'process_name': '53DF87F3-1A1A-494B-B412-3F265C8EF409', 'act_id': 520, 'act_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6', 'act_category': '02B6E7CE-EFE9-4C3B-9257-C5AE03ECD205', 'act_workload': 600, 'defaultStatus': 'assigned', 'workCadence': None, 'workersPerBox': None, 'prefweekend': 0, 'block_zone': 'Y', 'pra_seq': 1, 'pra_groupnum': None, 'pra_interval': None, 'pra_max_interval': None, 'pra_start_interval': None, 'pra_workload': None, 'PRA_PARA_ALIGN': None, 'requiredWorkers': '[{"ACR_QTY":5,"RE_NAME":"opérateur","RE_TYPE":"TEAM"}]', 'resource_type': 'EQUIPEMENT', 'resource_name': 'L1 - 04 - LYO B', 'resource_id': 935, 'equipment_category': 'UNDEFINED', 'resource_quantity': 0, 'resource_option': 'auto', 'equip_workload': None, 'start_date': datetime.datetime(2024, 11, 25, 1, 20), 'end_date': datetime.datetime(2024, 11, 25, 22, 0)}
# {'process_id': 201, 'process_name': '53DF87F3-1A1A-494B-B412-3F265C8EF409', 'act_id': 520, 'act_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6', 'act_category': '02B6E7CE-EFE9-4C3B-9257-C5AE03ECD205', 'act_workload': 600, 'defaultStatus': 'assigned', 'workCadence': None, 'workersPerBox': None, 'prefweekend': 0, 'block_zone': 'Y', 'pra_seq': 1, 'pra_groupnum': None, 'pra_interval': None, 'pra_max_interval': None, 'pra_start_interval': None, 'pra_workload': None, 'PRA_PARA_ALIGN': None, 'requiredWorkers': '[{"ACR_QTY":5,"RE_NAME":"opérateur","RE_TYPE":"TEAM"}]', 'resource_type': 'EQUIPEMENT', 'resource_name': 'L1 - 05 - LYO C', 'resource_id': 936, 'equipment_category': 'UNDEFINED', 'resource_quantity': 0, 'resource_option': 'auto', 'equip_workload': None, 'start_date': datetime.datetime(2024, 11, 25, 1, 20), 'end_date': datetime.datetime(2024, 11, 25, 22, 0)}
# {'process_id': 201, 'process_name': '53DF87F3-1A1A-494B-B412-3F265C8EF409', 'act_id': 520, 'act_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6', 'act_category': '02B6E7CE-EFE9-4C3B-9257-C5AE03ECD205', 'act_workload': 600, 'defaultStatus': 'assigned', 'workCadence': None, 'workersPerBox': None, 'prefweekend': 0, 'block_zone': 'Y', 'pra_seq': 1, 'pra_groupnum': None, 'pra_interval': None, 'pra_max_interval': None, 'pra_start_interval': None, 'pra_workload': None, 'PRA_PARA_ALIGN': None, 'requiredWorkers': '[{"ACR_QTY":5,"RE_NAME":"opérateur","RE_TYPE":"TEAM"}]', 'resource_type': 'EQUIPEMENT', 'resource_name': 'L1 - 06 -  LYO D', 'resource_id': 937, 'equipment_category': 'UNDEFINED', 'resource_quantity': 0, 'resource_option': 'auto', 'equip_workload': None, 'start_date': datetime.datetime(2024, 11, 25, 1, 20), 'end_date': datetime.datetime(2024, 11, 25, 22, 0)}
# {'process_id': 201, 'process_name': '53DF87F3-1A1A-494B-B412-3F265C8EF409', 'act_id': 520, 'act_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6', 'act_category': '02B6E7CE-EFE9-4C3B-9257-C5AE03ECD205', 'act_workload': 600, 'defaultStatus': 'assigned', 'workCadence': None, 'workersPerBox': None, 'prefweekend': 0, 'block_zone': 'Y', 'pra_seq': 1, 'pra_groupnum': None, 'pra_interval': None, 'pra_max_interval': None, 'pra_start_interval': None, 'pra_workload': None, 'PRA_PARA_ALIGN': None, 'requiredWorkers': '[{"ACR_QTY":5,"RE_NAME":"opérateur","RE_TYPE":"TEAM"}]', 'resource_type': 'ZONE', 'resource_name': 'Ligne 1 - Chargement', 'resource_id': 926, 'equipment_category': 'UNDEFINED', 'resource_quantity': 0, 'resource_option': 'auto', 'equip_workload': None, 'start_date': datetime.datetime(2024, 11, 25, 1, 20), 'end_date': datetime.datetime(2024, 11, 25, 22, 0)}
# {'process_id': 201, 'process_name': '53DF87F3-1A1A-494B-B412-3F265C8EF409', 'act_id': 520, 'act_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6', 'act_category': '02B6E7CE-EFE9-4C3B-9257-C5AE03ECD205', 'act_workload': 600, 'defaultStatus': 'assigned', 'workCadence': None, 'workersPerBox': None, 'prefweekend': 0, 'block_zone': 'Y', 'pra_seq': 1, 'pra_groupnum': None, 'pra_interval': None, 'pra_max_interval': None, 'pra_start_interval': None, 'pra_workload': None, 'PRA_PARA_ALIGN': None, 'requiredWorkers': '[{"ACR_QTY":5,"RE_NAME":"opérateur","RE_TYPE":"TEAM"}]', 'resource_type': 'EQUIPEMENT', 'resource_name': 'L1 - 01 - Isolateur Bosch', 'resource_id': 932, 'equipment_category': 'UNDEFINED', 'resource_quantity': 0, 'resource_option': 'required', 'equip_workload': 600, 'start_date': datetime.datetime(2024, 11, 25, 1, 20), 'end_date': datetime.datetime(2024, 11, 25, 22, 0)}
# {'process_id': 201, 'process_name': '53DF87F3-1A1A-494B-B412-3F265C8EF409', 'act_id': 520, 'act_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6', 'act_category': '02B6E7CE-EFE9-4C3B-9257-C5AE03ECD205', 'act_workload': 600, 'defaultStatus': 'assigned', 'workCadence': None, 'workersPerBox': None, 'prefweekend': 0, 'block_zone': 'Y', 'pra_seq': 1, 'pra_groupnum': None, 'pra_interval': None, 'pra_max_interval': None, 'pra_start_interval': None, 'pra_workload': None, 'PRA_PARA_ALIGN': None, 'requiredWorkers': '[{"ACR_QTY":5,"RE_NAME":"opérateur","RE_TYPE":"TEAM"}]', 'resource_type': 'TEAM', 'resource_name': 'opérateur', 'resource_id': 925, 'equipment_category': 'UNDEFINED', 'resource_quantity': 5, 'resource_option': 'auto', 'equip_workload': 0, 'start_date': datetime.datetime(2024, 11, 25, 1, 20), 'end_date': datetime.datetime(2024, 11, 25, 22, 0)}
# {'process_id': 201, 'process_name': '53DF87F3-1A1A-494B-B412-3F265C8EF409', 'act_id': 520, 'act_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6', 'act_category': '02B6E7CE-EFE9-4C3B-9257-C5AE03ECD205', 'act_workload': 600, 'defaultStatus': 'assigned', 'workCadence': None, 'workersPerBox': None, 'prefweekend': 0, 'block_zone': 'Y', 'pra_seq': 1, 'pra_groupnum': None, 'pra_interval': None, 'pra_max_interval': None, 'pra_start_interval': None, 'pra_workload': None, 'PRA_PARA_ALIGN': None, 'requiredWorkers': '[{"ACR_QTY":5,"RE_NAME":"opérateur","RE_TYPE":"TEAM"}]', 'resource_type': 'EQUIPEMENT', 'resource_name': 'L1 - 02 - Isolateur SKAN', 'resource_id': 933, 'equipment_category': 'UNDEFINED', 'resource_quantity': 0, 'resource_option': 'required', 'equip_workload': None, 'start_date': datetime.datetime(2024, 11, 25, 1, 20), 'end_date': datetime.datetime(2024, 11, 25, 22, 0)}
# {'process_id': 201, 'process_name': '53DF87F3-1A1A-494B-B412-3F265C8EF409', 'act_id': 520, 'act_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6', 'act_category': '02B6E7CE-EFE9-4C3B-9257-C5AE03ECD205', 'act_workload': 600, 'defaultStatus': 'assigned', 'workCadence': None, 'workersPerBox': None, 'prefweekend': 0, 'block_zone': 'Y', 'pra_seq': 1, 'pra_groupnum': None, 'pra_interval': None, 'pra_max_interval': None, 'pra_start_interval': None, 'pra_workload': None, 'PRA_PARA_ALIGN': None, 'requiredWorkers': '[{"ACR_QTY":5,"RE_NAME":"opérateur","RE_TYPE":"TEAM"}]', 'resource_type': 'EQUIPEMENT', 'resource_name': 'L1 - 03 - LYO A', 'resource_id': 934, 'equipment_category': 'UNDEFINED', 'resource_quantity': 0, 'resource_option': 'auto', 'equip_workload': None, 'start_date': datetime.datetime(2024, 11, 25, 1, 20), 'end_date': datetime.datetime(2024, 11, 25, 22, 0)}
# {'process_id': 201, 'process_name': '53DF87F3-1A1A-494B-B412-3F265C8EF409', 'act_id': 520, 'act_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6', 'act_category': '02B6E7CE-EFE9-4C3B-9257-C5AE03ECD205', 'act_workload': 600, 'defaultStatus': 'assigned', 'workCadence': None, 'workersPerBox': None, 'prefweekend': 0, 'block_zone': 'Y', 'pra_seq': 1, 'pra_groupnum': None, 'pra_interval': None, 'pra_max_interval': None, 'pra_start_interval': None, 'pra_workload': None, 'PRA_PARA_ALIGN': None, 'requiredWorkers': '[{"ACR_QTY":5,"RE_NAME":"opérateur","RE_TYPE":"TEAM"}]', 'resource_type': 'EQUIPEMENT', 'resource_name': 'L1 - 04 - LYO B', 'resource_id': 935, 'equipment_category': 'UNDEFINED', 'resource_quantity': 0, 'resource_option': 'auto', 'equip_workload': None, 'start_date': datetime.datetime(2024, 11, 25, 1, 20), 'end_date': datetime.datetime(2024, 11, 25, 22, 0)}
# {'process_id': 201, 'process_name': '53DF87F3-1A1A-494B-B412-3F265C8EF409', 'act_id': 520, 'act_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6', 'act_category': '02B6E7CE-EFE9-4C3B-9257-C5AE03ECD205', 'act_workload': 600, 'defaultStatus': 'assigned', 'workCadence': None, 'workersPerBox': None, 'prefweekend': 0, 'block_zone': 'Y', 'pra_seq': 1, 'pra_groupnum': None, 'pra_interval': None, 'pra_max_interval': None, 'pra_start_interval': None, 'pra_workload': None, 'PRA_PARA_ALIGN': None, 'requiredWorkers': '[{"ACR_QTY":5,"RE_NAME":"opérateur","RE_TYPE":"TEAM"}]', 'resource_type': 'EQUIPEMENT', 'resource_name': 'L1 - 05 - LYO C', 'resource_id': 936, 'equipment_category': 'UNDEFINED', 'resource_quantity': 0, 'resource_option': 'auto', 'equip_workload': None, 'start_date': datetime.datetime(2024, 11, 25, 1, 20), 'end_date': datetime.datetime(2024, 11, 25, 22, 0)}
# {'process_id': 201, 'process_name': '53DF87F3-1A1A-494B-B412-3F265C8EF409', 'act_id': 520, 'act_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6', 'act_category': '02B6E7CE-EFE9-4C3B-9257-C5AE03ECD205', 'act_workload': 600, 'defaultStatus': 'assigned', 'workCadence': None, 'workersPerBox': None, 'prefweekend': 0, 'block_zone': 'Y', 'pra_seq': 1, 'pra_groupnum': None, 'pra_interval': None, 'pra_max_interval': None, 'pra_start_interval': None, 'pra_workload': None, 'PRA_PARA_ALIGN': None, 'requiredWorkers': '[{"ACR_QTY":5,"RE_NAME":"opérateur","RE_TYPE":"TEAM"}]', 'resource_type': 'EQUIPEMENT', 'resource_name': 'L1 - 06 -  LYO D', 'resource_id': 937, 'equipment_category': 'UNDEFINED', 'resource_quantity': 0, 'resource_option': 'auto', 'equip_workload': None, 'start_date': datetime.datetime(2024, 11, 25, 1, 20), 'end_date': datetime.datetime(2024, 11, 25, 22, 0)}
#
# === EQUIPMENT ===
# {'equipment_id': 930, 'equipment_name': 'L8 - 2 - Intervention maint Corr L1', 'equipment_type': 'EQUIPEMENT', 'category': 'UNDEFINED', 'maintenanceRequired': 'N', 'parent_zone': None}
# {'equipment_id': 931, 'equipment_name': 'L9 - 2 - Intervention maint Corr L2', 'equipment_type': 'EQUIPEMENT', 'category': 'UNDEFINED', 'maintenanceRequired': 'N', 'parent_zone': None}
# {'equipment_id': 932, 'equipment_name': 'L1 - 01 - Isolateur Bosch', 'equipment_type': 'EQUIPEMENT', 'category': 'UNDEFINED', 'maintenanceRequired': 'Y', 'parent_zone': 926}
# {'equipment_id': 933, 'equipment_name': 'L1 - 02 - Isolateur SKAN', 'equipment_type': 'EQUIPEMENT', 'category': 'UNDEFINED', 'maintenanceRequired': 'Y', 'parent_zone': 926}
# {'equipment_id': 934, 'equipment_name': 'L1 - 03 - LYO A', 'equipment_type': 'EQUIPEMENT', 'category': 'UNDEFINED', 'maintenanceRequired': 'Y', 'parent_zone': 926}
# {'equipment_id': 935, 'equipment_name': 'L1 - 04 - LYO B', 'equipment_type': 'EQUIPEMENT', 'category': 'UNDEFINED', 'maintenanceRequired': 'Y', 'parent_zone': 926}
# {'equipment_id': 936, 'equipment_name': 'L1 - 05 - LYO C', 'equipment_type': 'EQUIPEMENT', 'category': 'UNDEFINED', 'maintenanceRequired': 'Y', 'parent_zone': 926}
# {'equipment_id': 937, 'equipment_name': 'L1 - 06 -  LYO D', 'equipment_type': 'EQUIPEMENT', 'category': 'UNDEFINED', 'maintenanceRequired': 'Y', 'parent_zone': 926}
# {'equipment_id': 938, 'equipment_name': 'L1 - 09 - Capsuleuse 1.1', 'equipment_type': 'EQUIPEMENT', 'category': 'UNDEFINED', 'maintenanceRequired': 'Y', 'parent_zone': 927}
# {'equipment_id': 939, 'equipment_name': 'L1 - 11 - SEIDENADER', 'equipment_type': 'EQUIPEMENT', 'category': 'UNDEFINED', 'maintenanceRequired': 'Y', 'parent_zone': 927}
# {'equipment_id': 940, 'equipment_name': 'L1 - 07 - DFT 1', 'equipment_type': 'EQUIPEMENT', 'category': 'UNDEFINED', 'maintenanceRequired': 'Y', 'parent_zone': 927}
# {'equipment_id': 941, 'equipment_name': 'L1 - 10 - Capsuleuse 1.2', 'equipment_type': 'EQUIPEMENT', 'category': 'UNDEFINED', 'maintenanceRequired': 'Y', 'parent_zone': 927}
# {'equipment_id': 942, 'equipment_name': 'L1 - 08 - DFT 2', 'equipment_type': 'EQUIPEMENT', 'category': 'UNDEFINED', 'maintenanceRequired': 'Y', 'parent_zone': 927}
# {'equipment_id': 943, 'equipment_name': 'L2 - 20 - Capsuleuse 2.1', 'equipment_type': 'EQUIPEMENT', 'category': 'UNDEFINED', 'maintenanceRequired': 'Y', 'parent_zone': 929}
# {'equipment_id': 944, 'equipment_name': 'L2 - 21 - Capsuleuse 2.2', 'equipment_type': 'EQUIPEMENT', 'category': 'UNDEFINED', 'maintenanceRequired': 'Y', 'parent_zone': 929}
# {'equipment_id': 945, 'equipment_name': 'L2 - 12 - Isolateur Bosch', 'equipment_type': 'EQUIPEMENT', 'category': 'UNDEFINED', 'maintenanceRequired': 'Y', 'parent_zone': 928}
# {'equipment_id': 946, 'equipment_name': 'L2 - 13 - Isolateur Skan', 'equipment_type': 'EQUIPEMENT', 'category': 'UNDEFINED', 'maintenanceRequired': 'Y', 'parent_zone': 928}
# {'equipment_id': 947, 'equipment_name': 'L2 - 14 - LYO E', 'equipment_type': 'EQUIPEMENT', 'category': 'UNDEFINED', 'maintenanceRequired': 'Y', 'parent_zone': 928}
# {'equipment_id': 948, 'equipment_name': 'L2 - 15 - LYO F', 'equipment_type': 'EQUIPEMENT', 'category': 'UNDEFINED', 'maintenanceRequired': 'Y', 'parent_zone': 928}
# {'equipment_id': 949, 'equipment_name': 'L2 - 16 - LYO G', 'equipment_type': 'EQUIPEMENT', 'category': 'UNDEFINED', 'maintenanceRequired': 'Y', 'parent_zone': 928}
# {'equipment_id': 950, 'equipment_name': 'L2 - 17 - LYO H', 'equipment_type': 'EQUIPEMENT', 'category': 'UNDEFINED', 'maintenanceRequired': 'Y', 'parent_zone': 928}
# {'equipment_id': 951, 'equipment_name': 'L2 - 18 - DFT 3', 'equipment_type': 'EQUIPEMENT', 'category': 'UNDEFINED', 'maintenanceRequired': 'Y', 'parent_zone': 929}
# {'equipment_id': 952, 'equipment_name': 'L2 - 19 - DFT 4', 'equipment_type': 'EQUIPEMENT', 'category': 'UNDEFINED', 'maintenanceRequired': 'Y', 'parent_zone': 929}
# {'equipment_id': 953, 'equipment_name': 'L2 - 22 - Seidenader', 'equipment_type': 'EQUIPEMENT', 'category': 'UNDEFINED', 'maintenanceRequired': 'Y', 'parent_zone': 929}
# {'equipment_id': 954, 'equipment_name': 'L2 - 11 - Taches annexes', 'equipment_type': 'EQUIPEMENT', 'category': 'UNDEFINED', 'maintenanceRequired': 'Y', 'parent_zone': 928}
# {'equipment_id': 955, 'equipment_name': 'L1 - 00 - Suivi cuve', 'equipment_type': 'EQUIPEMENT', 'category': 'UNDEFINED', 'maintenanceRequired': 'N', 'parent_zone': 926}
# {'equipment_id': 956, 'equipment_name': 'L1 - 00 - Taches annexes', 'equipment_type': 'EQUIPEMENT', 'category': 'UNDEFINED', 'maintenanceRequired': 'N', 'parent_zone': 926}
# {'equipment_id': 957, 'equipment_name': 'L2 - 00 - Suivi cuve', 'equipment_type': 'EQUIPEMENT', 'category': 'UNDEFINED', 'maintenanceRequired': 'N', 'parent_zone': 928}
#
# === WORKERS ===
# 1552 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1554 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1555 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1556 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1557 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1558 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1559 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1560 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1561 {'firstName': None, 'lastName': None, 'team_name': 'Classificateur'}
# 1562 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1563 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1564 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1565 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1566 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1567 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1568 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1569 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1570 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1571 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1572 {'firstName': None, 'lastName': None, 'team_name': 'Classificateur'}
# 1573 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1574 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1575 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1576 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1577 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1578 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1579 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1580 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1582 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1584 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1586 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1587 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1588 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1589 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1590 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1591 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1592 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1593 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1594 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1595 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1597 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1598 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1599 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1600 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1601 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1602 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1604 {'firstName': None, 'lastName': None, 'team_name': 'Classificateur'}
# 1605 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1606 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1607 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1608 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1609 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1610 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1611 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1612 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1613 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1614 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1615 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1616 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1617 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1618 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1619 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1620 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1621 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1622 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1623 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1625 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1626 {'firstName': None, 'lastName': None, 'team_name': 'OP OS'}
# 1627 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1628 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1629 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1630 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1631 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1632 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1633 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1634 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1635 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1636 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1637 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1638 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1639 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1640 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1641 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1642 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1643 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1644 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1645 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1647 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1648 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1649 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1650 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1651 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1652 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1653 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1654 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1655 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1656 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1657 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1658 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1659 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1660 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1661 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1662 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1663 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1664 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1665 {'firstName': None, 'lastName': None, 'team_name': 'Classificateur'}
# 1667 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1668 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1669 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1670 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1671 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1672 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1673 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1674 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1675 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1676 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1677 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1678 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1679 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1680 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1681 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1682 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1684 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1685 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1688 {'firstName': None, 'lastName': None, 'team_name': 'OP OS'}
# 1691 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1692 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1693 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1694 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1695 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1696 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1697 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1698 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1699 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1700 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1701 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1702 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1703 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1704 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1705 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1706 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1707 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1708 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1709 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1710 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1711 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1712 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1713 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1714 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1715 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1716 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1717 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1718 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1719 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1720 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1721 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1722 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1723 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1724 {'firstName': None, 'lastName': None, 'team_name': 'OP OS'}
# 1725 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1726 {'firstName': None, 'lastName': None, 'team_name': 'opérateur'}
# 1727 {'firstName': None, 'lastName': None, 'team_name': 'OP VI'}
#
# === ZONES ===
# {'zone_id': 926, 'zone_name': 'Ligne 1 - Chargement', 'zone_type': 'ZONE', 'category': 'UNDEFINED', 'maintenanceRequired': None, 'parent_zone': None}
# {'zone_id': 927, 'zone_name': 'Ligne 1 - Déchargement', 'zone_type': 'ZONE', 'category': 'UNDEFINED', 'maintenanceRequired': None, 'parent_zone': None}
# {'zone_id': 928, 'zone_name': 'Ligne 2 - Chargement', 'zone_type': 'ZONE', 'category': 'UNDEFINED', 'maintenanceRequired': None, 'parent_zone': None}
# {'zone_id': 929, 'zone_name': 'Ligne 2 - Déchargement', 'zone_type': 'ZONE', 'category': 'UNDEFINED', 'maintenanceRequired': None, 'parent_zone': None}
#
# === SHIFTS ===
# Worker 1727 has shifts:
#   (360, 820, datetime.date(2024, 10, 17))
#   (360, 820, datetime.date(2024, 10, 15))
#   (360, 820, datetime.date(2024, 10, 11))
#   (360, 820, datetime.date(2024, 10, 9))
#   (360, 820, datetime.date(2024, 10, 7))
#   (360, 820, datetime.date(2024, 10, 3))
#   (360, 820, datetime.date(2024, 10, 1))
#   (1080, 1780, datetime.date(2024, 10, 18))
#   (1080, 1780, datetime.date(2024, 10, 14))
#   (1080, 1780, datetime.date(2024, 10, 10))
#   (1080, 1780, datetime.date(2024, 10, 4))
#   (1080, 1780, datetime.date(2024, 10, 2))
# Worker 1726 has shifts:
#   (360, 820, datetime.date(2024, 10, 17))
#   (360, 820, datetime.date(2024, 10, 15))
#   (360, 820, datetime.date(2024, 10, 11))
#   (360, 820, datetime.date(2024, 10, 9))
#   (360, 820, datetime.date(2024, 10, 7))
#   (360, 820, datetime.date(2024, 10, 3))
#   (360, 820, datetime.date(2024, 10, 1))
#   (1080, 1780, datetime.date(2024, 10, 18))
#   (1080, 1780, datetime.date(2024, 10, 14))
#   (1080, 1780, datetime.date(2024, 10, 10))
#   (1080, 1780, datetime.date(2024, 10, 4))
#   (1080, 1780, datetime.date(2024, 10, 2))
# Worker 1725 has shifts:
#   (360, 820, datetime.date(2024, 10, 17))
#   (360, 820, datetime.date(2024, 10, 15))
#   (360, 820, datetime.date(2024, 10, 11))
#   (360, 820, datetime.date(2024, 10, 9))
#   (360, 820, datetime.date(2024, 10, 7))
#   (360, 820, datetime.date(2024, 10, 3))
#   (360, 820, datetime.date(2024, 10, 1))
#   (1080, 1780, datetime.date(2024, 10, 18))
#   (1080, 1780, datetime.date(2024, 10, 14))
#   (1080, 1780, datetime.date(2024, 10, 10))
#   (1080, 1780, datetime.date(2024, 10, 4))
#   (1080, 1780, datetime.date(2024, 10, 2))
# Worker 1724 has shifts:
#   (360, 820, datetime.date(2024, 10, 17))
#   (360, 820, datetime.date(2024, 10, 15))
#   (360, 820, datetime.date(2024, 10, 11))
#   (360, 820, datetime.date(2024, 10, 9))
#   (360, 820, datetime.date(2024, 10, 7))
#   (360, 820, datetime.date(2024, 10, 3))
#   (360, 820, datetime.date(2024, 10, 1))
#   (1080, 1780, datetime.date(2024, 10, 18))
#   (1080, 1780, datetime.date(2024, 10, 14))
#   (1080, 1780, datetime.date(2024, 10, 10))
#   (1080, 1780, datetime.date(2024, 10, 4))
#   (1080, 1780, datetime.date(2024, 10, 2))
# Worker 1723 has shifts:
#   (360, 820, datetime.date(2024, 10, 17))
#   (360, 820, datetime.date(2024, 10, 15))
#   (360, 820, datetime.date(2024, 10, 11))
#   (360, 820, datetime.date(2024, 10, 9))
#   (360, 820, datetime.date(2024, 10, 7))
#   (360, 820, datetime.date(2024, 10, 3))
#   (360, 820, datetime.date(2024, 10, 1))
#   (1080, 1780, datetime.date(2024, 10, 18))
#   (1080, 1780, datetime.date(2024, 10, 14))
#   (1080, 1780, datetime.date(2024, 10, 10))
#   (1080, 1780, datetime.date(2024, 10, 4))
#   (1080, 1780, datetime.date(2024, 10, 2))
# Worker 1722 has shifts:
#   (360, 820, datetime.date(2024, 10, 17))
#   (360, 820, datetime.date(2024, 10, 15))
#   (360, 820, datetime.date(2024, 10, 11))
#   (360, 820, datetime.date(2024, 10, 9))
#   (360, 820, datetime.date(2024, 10, 7))
#   (360, 820, datetime.date(2024, 10, 3))
#   (360, 820, datetime.date(2024, 10, 1))
#   (1080, 1780, datetime.date(2024, 10, 18))
#   (1080, 1780, datetime.date(2024, 10, 14))
#   (1080, 1780, datetime.date(2024, 10, 10))
#   (1080, 1780, datetime.date(2024, 10, 4))
#   (1080, 1780, datetime.date(2024, 10, 2))
# Worker 1721 has shifts:
#   (360, 820, datetime.date(2024, 10, 17))
#   (360, 820, datetime.date(2024, 10, 15))
#   (360, 820, datetime.date(2024, 10, 11))
#   (360, 820, datetime.date(2024, 10, 9))
#   (360, 820, datetime.date(2024, 10, 7))
#   (360, 820, datetime.date(2024, 10, 3))
#   (360, 820, datetime.date(2024, 10, 1))
#   (1080, 1780, datetime.date(2024, 10, 18))
#   (1080, 1780, datetime.date(2024, 10, 14))
#   (1080, 1780, datetime.date(2024, 10, 10))
#   (1080, 1780, datetime.date(2024, 10, 4))
#   (1080, 1780, datetime.date(2024, 10, 2))
# Worker 1720 has shifts:
#   (360, 820, datetime.date(2024, 10, 17))
#   (360, 820, datetime.date(2024, 10, 15))
#   (360, 820, datetime.date(2024, 10, 11))
#   (360, 820, datetime.date(2024, 10, 9))
#   (360, 820, datetime.date(2024, 10, 7))
#   (360, 820, datetime.date(2024, 10, 3))
#   (360, 820, datetime.date(2024, 10, 1))
#   (1080, 1780, datetime.date(2024, 10, 18))
#   (1080, 1780, datetime.date(2024, 10, 14))
#   (1080, 1780, datetime.date(2024, 10, 10))
#   (1080, 1780, datetime.date(2024, 10, 4))
#   (1080, 1780, datetime.date(2024, 10, 2))
# Worker 1719 has shifts:
#   (360, 820, datetime.date(2024, 10, 17))
#   (360, 820, datetime.date(2024, 10, 15))
#   (360, 820, datetime.date(2024, 10, 11))
#   (360, 820, datetime.date(2024, 10, 9))
#   (360, 820, datetime.date(2024, 10, 7))
#   (360, 820, datetime.date(2024, 10, 3))
#   (360, 820, datetime.date(2024, 10, 1))
#   (1080, 1780, datetime.date(2024, 10, 18))
#   (1080, 1780, datetime.date(2024, 10, 14))
#   (1080, 1780, datetime.date(2024, 10, 10))
#   (1080, 1780, datetime.date(2024, 10, 4))
#   (1080, 1780, datetime.date(2024, 10, 2))
# Worker 1718 has shifts:
#   (360, 820, datetime.date(2024, 10, 17))
#   (360, 820, datetime.date(2024, 10, 15))
#   (360, 820, datetime.date(2024, 10, 11))
#   (360, 820, datetime.date(2024, 10, 9))
#   (360, 820, datetime.date(2024, 10, 7))
#   (360, 820, datetime.date(2024, 10, 3))
#   (360, 820, datetime.date(2024, 10, 1))
#   (1080, 1780, datetime.date(2024, 10, 18))
#   (1080, 1780, datetime.date(2024, 10, 14))
# ...
# Worker 1584 has shifts:
#   (360, 820, datetime.date(2024, 10, 17))
#   (360, 820, datetime.date(2024, 10, 15))
#   (360, 820, datetime.date(2024, 10, 11))
#   (360, 820, datetime.date(2024, 10, 9))
#   (360, 820, datetime.date(2024, 10, 7))
#   (360, 820, datetime.date(2024, 10, 3))
#   (360, 820, datetime.date(2024, 10, 1))
#   (1080, 1780, datetime.date(2024, 10, 18))
#   (1080, 1780, datetime.date(2024, 10, 14))
#   (1080, 1780, datetime.date(2024, 10, 10))
#   (1080, 1780, datetime.date(2024, 10, 4))
#   (1080, 1780, datetime.date(2024, 10, 2))
# Worker 1582 has shifts:
#   (360, 820, datetime.date(2024, 10, 17))
#   (360, 820, datetime.date(2024, 10, 15))
#   (360, 820, datetime.date(2024, 10, 11))
#   (360, 820, datetime.date(2024, 10, 9))
#   (360, 820, datetime.date(2024, 10, 7))
#   (360, 820, datetime.date(2024, 10, 3))
#   (360, 820, datetime.date(2024, 10, 1))
#   (1080, 1780, datetime.date(2024, 10, 18))
#   (1080, 1780, datetime.date(2024, 10, 14))
#   (1080, 1780, datetime.date(2024, 10, 10))
#   (1080, 1780, datetime.date(2024, 10, 4))
#   (1080, 1780, datetime.date(2024, 10, 2))
# Worker 1580 has shifts:
#   (360, 820, datetime.date(2024, 10, 17))
#   (360, 820, datetime.date(2024, 10, 15))
#   (360, 820, datetime.date(2024, 10, 11))
#   (360, 820, datetime.date(2024, 10, 9))
#   (360, 820, datetime.date(2024, 10, 7))
#   (360, 820, datetime.date(2024, 10, 3))
#   (360, 820, datetime.date(2024, 10, 1))
#   (1080, 1780, datetime.date(2024, 10, 18))
#   (1080, 1780, datetime.date(2024, 10, 14))
#   (1080, 1780, datetime.date(2024, 10, 10))
#   (1080, 1780, datetime.date(2024, 10, 4))
#   (1080, 1780, datetime.date(2024, 10, 2))
# Worker 1579 has shifts:
#   (360, 820, datetime.date(2024, 10, 17))
#   (360, 820, datetime.date(2024, 10, 15))
#   (360, 820, datetime.date(2024, 10, 11))
#   (360, 820, datetime.date(2024, 10, 9))
#   (360, 820, datetime.date(2024, 10, 7))
#   (360, 820, datetime.date(2024, 10, 3))
#   (360, 820, datetime.date(2024, 10, 1))
#   (1080, 1780, datetime.date(2024, 10, 18))
#   (1080, 1780, datetime.date(2024, 10, 14))
#   (1080, 1780, datetime.date(2024, 10, 10))
#   (1080, 1780, datetime.date(2024, 10, 4))
#   (1080, 1780, datetime.date(2024, 10, 2))
# Worker 1578 has shifts:
#   (360, 820, datetime.date(2024, 10, 17))
#   (360, 820, datetime.date(2024, 10, 15))
#   (360, 820, datetime.date(2024, 10, 11))
#   (360, 820, datetime.date(2024, 10, 9))
#   (360, 820, datetime.date(2024, 10, 7))
#   (360, 820, datetime.date(2024, 10, 3))
#   (360, 820, datetime.date(2024, 10, 1))
#   (1080, 1780, datetime.date(2024, 10, 18))
#   (1080, 1780, datetime.date(2024, 10, 14))
#   (1080, 1780, datetime.date(2024, 10, 10))
#   (1080, 1780, datetime.date(2024, 10, 4))
#   (1080, 1780, datetime.date(2024, 10, 2))
# Worker 1577 has shifts:
#   (360, 820, datetime.date(2024, 10, 17))
#   (360, 820, datetime.date(2024, 10, 15))
#   (360, 820, datetime.date(2024, 10, 11))
#   (360, 820, datetime.date(2024, 10, 9))
#   (360, 820, datetime.date(2024, 10, 7))
#   (360, 820, datetime.date(2024, 10, 3))
#   (360, 820, datetime.date(2024, 10, 1))
#   (1080, 1780, datetime.date(2024, 10, 18))
#   (1080, 1780, datetime.date(2024, 10, 14))
#   (1080, 1780, datetime.date(2024, 10, 10))
#   (1080, 1780, datetime.date(2024, 10, 4))
#   (1080, 1780, datetime.date(2024, 10, 2))
# Worker 1576 has shifts:
#   (360, 820, datetime.date(2024, 10, 17))
#   (360, 820, datetime.date(2024, 10, 15))
#   (360, 820, datetime.date(2024, 10, 11))
#   (360, 820, datetime.date(2024, 10, 9))
#   (360, 820, datetime.date(2024, 10, 7))
#   (360, 820, datetime.date(2024, 10, 3))
#   (360, 820, datetime.date(2024, 10, 1))
#   (1080, 1780, datetime.date(2024, 10, 18))
#   (1080, 1780, datetime.date(2024, 10, 14))
#   (1080, 1780, datetime.date(2024, 10, 10))
#   (1080, 1780, datetime.date(2024, 10, 4))
#   (1080, 1780, datetime.date(2024, 10, 2))
# Worker 1575 has shifts:
#   (360, 820, datetime.date(2024, 10, 17))
#   (360, 820, datetime.date(2024, 10, 15))
#   (360, 820, datetime.date(2024, 10, 11))
#   (360, 820, datetime.date(2024, 10, 9))
#   (360, 820, datetime.date(2024, 10, 7))
#   (360, 820, datetime.date(2024, 10, 3))
#   (360, 820, datetime.date(2024, 10, 1))
#   (1080, 1780, datetime.date(2024, 10, 18))
#   (1080, 1780, datetime.date(2024, 10, 14))
#   (1080, 1780, datetime.date(2024, 10, 10))
#   (1080, 1780, datetime.date(2024, 10, 4))
#   (1080, 1780, datetime.date(2024, 10, 2))
# Worker 1574 has shifts:
#   (360, 820, datetime.date(2024, 10, 17))
#   (360, 820, datetime.date(2024, 10, 15))
#   (360, 820, datetime.date(2024, 10, 11))
#   (360, 820, datetime.date(2024, 10, 9))
#   (360, 820, datetime.date(2024, 10, 7))
#   (360, 820, datetime.date(2024, 10, 3))
#   (360, 820, datetime.date(2024, 10, 1))
#   (1080, 1780, datetime.date(2024, 10, 18))
#   (1080, 1780, datetime.date(2024, 10, 14))
#   (1080, 1780, datetime.date(2024, 10, 10))
#   (1080, 1780, datetime.date(2024, 10, 4))
#   (1080, 1780, datetime.date(2024, 10, 2))
# Worker 1573 has shifts:
#   (360, 820, datetime.date(2024, 10, 17))
#   (360, 820, datetime.date(2024, 10, 15))
#   (360, 820, datetime.date(2024, 10, 11))
#   (360, 820, datetime.date(2024, 10, 9))
#   (360, 820, datetime.date(2024, 10, 7))
#   (360, 820, datetime.date(2024, 10, 3))
#   (360, 820, datetime.date(2024, 10, 1))
#   (1080, 1780, datetime.date(2024, 10, 18))
#   (1080, 1780, datetime.date(2024, 10, 14))
#   (1080, 1780, datetime.date(2024, 10, 10))
#   (1080, 1780, datetime.date(2024, 10, 4))
#   (1080, 1780, datetime.date(2024, 10, 2))
# Worker 1572 has shifts:
#   (360, 820, datetime.date(2024, 10, 17))
#   (360, 820, datetime.date(2024, 10, 15))
#   (360, 820, datetime.date(2024, 10, 11))
#   (360, 820, datetime.date(2024, 10, 9))
#   (360, 820, datetime.date(2024, 10, 7))
#   (360, 820, datetime.date(2024, 10, 3))
#   (360, 820, datetime.date(2024, 10, 1))
#   (1080, 1780, datetime.date(2024, 10, 18))
#   (1080, 1780, datetime.date(2024, 10, 14))
#   (1080, 1780, datetime.date(2024, 10, 10))
#   (1080, 1780, datetime.date(2024, 10, 4))
#   (1080, 1780, datetime.date(2024, 10, 2))
# Worker 1571 has shifts:
#   (360, 820, datetime.date(2024, 10, 17))
#   (360, 820, datetime.date(2024, 10, 15))
#   (360, 820, datetime.date(2024, 10, 11))
#   (360, 820, datetime.date(2024, 10, 9))
#   (360, 820, datetime.date(2024, 10, 7))
#   (360, 820, datetime.date(2024, 10, 3))
#   (360, 820, datetime.date(2024, 10, 1))
#   (1080, 1780, datetime.date(2024, 10, 18))
#   (1080, 1780, datetime.date(2024, 10, 14))
#   (1080, 1780, datetime.date(2024, 10, 10))
#   (1080, 1780, datetime.date(2024, 10, 4))
#   (1080, 1780, datetime.date(2024, 10, 2))
# Worker 1570 has shifts:
#   (360, 820, datetime.date(2024, 10, 17))
#   (360, 820, datetime.date(2024, 10, 15))
#   (360, 820, datetime.date(2024, 10, 11))
#   (360, 820, datetime.date(2024, 10, 9))
#   (360, 820, datetime.date(2024, 10, 7))
#   (360, 820, datetime.date(2024, 10, 3))
#   (360, 820, datetime.date(2024, 10, 1))
#   (1080, 1780, datetime.date(2024, 10, 18))
#   (1080, 1780, datetime.date(2024, 10, 14))
#   (1080, 1780, datetime.date(2024, 10, 10))
#   (1080, 1780, datetime.date(2024, 10, 4))
#   (1080, 1780, datetime.date(2024, 10, 2))
# Worker 1569 has shifts:
#   (360, 820, datetime.date(2024, 10, 17))
#   (360, 820, datetime.date(2024, 10, 15))
#   (360, 820, datetime.date(2024, 10, 11))
#   (360, 820, datetime.date(2024, 10, 9))
#   (360, 820, datetime.date(2024, 10, 7))
#   (360, 820, datetime.date(2024, 10, 3))
#   (360, 820, datetime.date(2024, 10, 1))
#   (1080, 1780, datetime.date(2024, 10, 18))
#   (1080, 1780, datetime.date(2024, 10, 14))
#   (1080, 1780, datetime.date(2024, 10, 10))
#   (1080, 1780, datetime.date(2024, 10, 4))
#   (1080, 1780, datetime.date(2024, 10, 2))
# Worker 1568 has shifts:
#   (360, 820, datetime.date(2024, 10, 17))
#   (360, 820, datetime.date(2024, 10, 15))
#   (360, 820, datetime.date(2024, 10, 11))
#   (360, 820, datetime.date(2024, 10, 9))
#   (360, 820, datetime.date(2024, 10, 7))
#   (360, 820, datetime.date(2024, 10, 3))
#   (360, 820, datetime.date(2024, 10, 1))
#   (1080, 1780, datetime.date(2024, 10, 18))
#   (1080, 1780, datetime.date(2024, 10, 14))
#   (1080, 1780, datetime.date(2024, 10, 10))
#   (1080, 1780, datetime.date(2024, 10, 4))
#   (1080, 1780, datetime.date(2024, 10, 2))
# Worker 1567 has shifts:
#   (360, 820, datetime.date(2024, 10, 17))
#   (360, 820, datetime.date(2024, 10, 15))
#   (360, 820, datetime.date(2024, 10, 11))
#   (360, 820, datetime.date(2024, 10, 9))
#   (360, 820, datetime.date(2024, 10, 7))
#   (360, 820, datetime.date(2024, 10, 3))
#   (360, 820, datetime.date(2024, 10, 1))
#   (1080, 1780, datetime.date(2024, 10, 18))
#   (1080, 1780, datetime.date(2024, 10, 14))
#   (1080, 1780, datetime.date(2024, 10, 10))
#   (1080, 1780, datetime.date(2024, 10, 4))
#   (1080, 1780, datetime.date(2024, 10, 2))
# Worker 1566 has shifts:
#   (360, 820, datetime.date(2024, 10, 17))
#   (360, 820, datetime.date(2024, 10, 15))
#   (360, 820, datetime.date(2024, 10, 11))
#   (360, 820, datetime.date(2024, 10, 9))
#   (360, 820, datetime.date(2024, 10, 7))
#   (360, 820, datetime.date(2024, 10, 3))
#   (360, 820, datetime.date(2024, 10, 1))
#   (1080, 1780, datetime.date(2024, 10, 18))
#   (1080, 1780, datetime.date(2024, 10, 14))
#   (1080, 1780, datetime.date(2024, 10, 10))
#   (1080, 1780, datetime.date(2024, 10, 4))
#   (1080, 1780, datetime.date(2024, 10, 2))
# Worker 1565 has shifts:
#   (360, 820, datetime.date(2024, 10, 17))
#   (360, 820, datetime.date(2024, 10, 15))
#   (360, 820, datetime.date(2024, 10, 11))
#   (360, 820, datetime.date(2024, 10, 9))
#   (360, 820, datetime.date(2024, 10, 7))
#   (360, 820, datetime.date(2024, 10, 3))
#   (360, 820, datetime.date(2024, 10, 1))
#   (1080, 1780, datetime.date(2024, 10, 18))
#   (1080, 1780, datetime.date(2024, 10, 14))
#   (1080, 1780, datetime.date(2024, 10, 10))
#   (1080, 1780, datetime.date(2024, 10, 4))
#   (1080, 1780, datetime.date(2024, 10, 2))
# Worker 1564 has shifts:
#   (360, 820, datetime.date(2024, 10, 17))
#   (360, 820, datetime.date(2024, 10, 15))
#   (360, 820, datetime.date(2024, 10, 11))
#   (360, 820, datetime.date(2024, 10, 9))
#   (360, 820, datetime.date(2024, 10, 7))
#   (360, 820, datetime.date(2024, 10, 3))
#   (360, 820, datetime.date(2024, 10, 1))
#   (1080, 1780, datetime.date(2024, 10, 18))
#   (1080, 1780, datetime.date(2024, 10, 14))
#   (1080, 1780, datetime.date(2024, 10, 10))
#   (1080, 1780, datetime.date(2024, 10, 4))
#   (1080, 1780, datetime.date(2024, 10, 2))
# Worker 1563 has shifts:
#   (360, 820, datetime.date(2024, 10, 17))
#   (360, 820, datetime.date(2024, 10, 15))
#   (360, 820, datetime.date(2024, 10, 11))
#   (360, 820, datetime.date(2024, 10, 9))
#   (360, 820, datetime.date(2024, 10, 7))
#   (360, 820, datetime.date(2024, 10, 3))
#   (360, 820, datetime.date(2024, 10, 1))
#   (1080, 1780, datetime.date(2024, 10, 18))
#   (1080, 1780, datetime.date(2024, 10, 14))
#   (1080, 1780, datetime.date(2024, 10, 10))
#   (1080, 1780, datetime.date(2024, 10, 4))
#   (1080, 1780, datetime.date(2024, 10, 2))
# Worker 1562 has shifts:
#   (360, 820, datetime.date(2024, 10, 17))
#   (360, 820, datetime.date(2024, 10, 15))
#   (360, 820, datetime.date(2024, 10, 11))
#   (360, 820, datetime.date(2024, 10, 9))
#   (360, 820, datetime.date(2024, 10, 7))
#   (360, 820, datetime.date(2024, 10, 3))
#   (360, 820, datetime.date(2024, 10, 1))
#   (1080, 1780, datetime.date(2024, 10, 18))
#   (1080, 1780, datetime.date(2024, 10, 14))
#   (1080, 1780, datetime.date(2024, 10, 10))
#   (1080, 1780, datetime.date(2024, 10, 4))
#   (1080, 1780, datetime.date(2024, 10, 2))
# Worker 1561 has shifts:
#   (360, 820, datetime.date(2024, 10, 17))
#   (360, 820, datetime.date(2024, 10, 15))
#   (360, 820, datetime.date(2024, 10, 11))
#   (360, 820, datetime.date(2024, 10, 9))
#   (360, 820, datetime.date(2024, 10, 7))
#   (360, 820, datetime.date(2024, 10, 3))
#   (360, 820, datetime.date(2024, 10, 1))
#   (1080, 1780, datetime.date(2024, 10, 18))
#   (1080, 1780, datetime.date(2024, 10, 14))
#   (1080, 1780, datetime.date(2024, 10, 10))
#   (1080, 1780, datetime.date(2024, 10, 4))
#   (1080, 1780, datetime.date(2024, 10, 2))
# Worker 1560 has shifts:
#   (360, 820, datetime.date(2024, 10, 17))
#   (360, 820, datetime.date(2024, 10, 15))
#   (360, 820, datetime.date(2024, 10, 11))
#   (360, 820, datetime.date(2024, 10, 9))
#   (360, 820, datetime.date(2024, 10, 7))
#   (360, 820, datetime.date(2024, 10, 3))
#   (360, 820, datetime.date(2024, 10, 1))
#   (1080, 1780, datetime.date(2024, 10, 18))
#   (1080, 1780, datetime.date(2024, 10, 14))
#   (1080, 1780, datetime.date(2024, 10, 10))
#   (1080, 1780, datetime.date(2024, 10, 4))
#   (1080, 1780, datetime.date(2024, 10, 2))
# Worker 1559 has shifts:
#   (360, 820, datetime.date(2024, 10, 17))
#   (360, 820, datetime.date(2024, 10, 15))
#   (360, 820, datetime.date(2024, 10, 11))
#   (360, 820, datetime.date(2024, 10, 9))
#   (360, 820, datetime.date(2024, 10, 7))
#   (360, 820, datetime.date(2024, 10, 3))
#   (360, 820, datetime.date(2024, 10, 1))
#   (1080, 1780, datetime.date(2024, 10, 18))
#   (1080, 1780, datetime.date(2024, 10, 14))
#   (1080, 1780, datetime.date(2024, 10, 10))
#   (1080, 1780, datetime.date(2024, 10, 4))
#   (1080, 1780, datetime.date(2024, 10, 2))
# Worker 1558 has shifts:
#   (360, 820, datetime.date(2024, 10, 17))
#   (360, 820, datetime.date(2024, 10, 15))
#   (360, 820, datetime.date(2024, 10, 11))
#   (360, 820, datetime.date(2024, 10, 9))
#   (360, 820, datetime.date(2024, 10, 7))
#   (360, 820, datetime.date(2024, 10, 3))
#   (360, 820, datetime.date(2024, 10, 1))
#   (1080, 1780, datetime.date(2024, 10, 18))
#   (1080, 1780, datetime.date(2024, 10, 14))
#   (1080, 1780, datetime.date(2024, 10, 10))
#   (1080, 1780, datetime.date(2024, 10, 4))
#   (1080, 1780, datetime.date(2024, 10, 2))
# Worker 1557 has shifts:
#   (360, 820, datetime.date(2024, 10, 17))
#   (360, 820, datetime.date(2024, 10, 15))
#   (360, 820, datetime.date(2024, 10, 11))
#   (360, 820, datetime.date(2024, 10, 9))
#   (360, 820, datetime.date(2024, 10, 7))
#   (360, 820, datetime.date(2024, 10, 3))
#   (360, 820, datetime.date(2024, 10, 1))
#   (1080, 1780, datetime.date(2024, 10, 18))
#   (1080, 1780, datetime.date(2024, 10, 14))
#   (1080, 1780, datetime.date(2024, 10, 10))
#   (1080, 1780, datetime.date(2024, 10, 4))
#   (1080, 1780, datetime.date(2024, 10, 2))
# Worker 1556 has shifts:
#   (360, 820, datetime.date(2024, 10, 17))
#   (360, 820, datetime.date(2024, 10, 15))
#   (360, 820, datetime.date(2024, 10, 11))
#   (360, 820, datetime.date(2024, 10, 9))
#   (360, 820, datetime.date(2024, 10, 7))
#   (360, 820, datetime.date(2024, 10, 3))
#   (360, 820, datetime.date(2024, 10, 1))
#   (1080, 1780, datetime.date(2024, 10, 18))
#   (1080, 1780, datetime.date(2024, 10, 14))
#   (1080, 1780, datetime.date(2024, 10, 10))
#   (1080, 1780, datetime.date(2024, 10, 4))
#   (1080, 1780, datetime.date(2024, 10, 2))
# Worker 1555 has shifts:
#   (360, 820, datetime.date(2024, 10, 17))
#   (360, 820, datetime.date(2024, 10, 15))
#   (360, 820, datetime.date(2024, 10, 11))
#   (360, 820, datetime.date(2024, 10, 9))
#   (360, 820, datetime.date(2024, 10, 7))
#   (360, 820, datetime.date(2024, 10, 3))
#   (360, 820, datetime.date(2024, 10, 1))
#   (1080, 1780, datetime.date(2024, 10, 18))
#   (1080, 1780, datetime.date(2024, 10, 14))
#   (1080, 1780, datetime.date(2024, 10, 10))
#   (1080, 1780, datetime.date(2024, 10, 4))
#   (1080, 1780, datetime.date(2024, 10, 2))
# Worker 1554 has shifts:
#   (360, 820, datetime.date(2024, 10, 17))
#   (360, 820, datetime.date(2024, 10, 15))
#   (360, 820, datetime.date(2024, 10, 11))
#   (360, 820, datetime.date(2024, 10, 9))
#   (360, 820, datetime.date(2024, 10, 7))
#   (360, 820, datetime.date(2024, 10, 3))
#   (360, 820, datetime.date(2024, 10, 1))
#   (1080, 1780, datetime.date(2024, 10, 18))
#   (1080, 1780, datetime.date(2024, 10, 14))
#   (1080, 1780, datetime.date(2024, 10, 10))
#   (1080, 1780, datetime.date(2024, 10, 4))
#   (1080, 1780, datetime.date(2024, 10, 2))
# Worker 1552 has shifts:
#   (360, 820, datetime.date(2024, 10, 17))
#   (360, 820, datetime.date(2024, 10, 15))
#   (360, 820, datetime.date(2024, 10, 11))
#   (360, 820, datetime.date(2024, 10, 9))
#   (360, 820, datetime.date(2024, 10, 7))
#   (360, 820, datetime.date(2024, 10, 3))
#   (360, 820, datetime.date(2024, 10, 1))
#   (1080, 1780, datetime.date(2024, 10, 18))
#   (1080, 1780, datetime.date(2024, 10, 14))
#   (1080, 1780, datetime.date(2024, 10, 10))
#   (1080, 1780, datetime.date(2024, 10, 4))
#   (1080, 1780, datetime.date(2024, 10, 2))

# %%
grouped = defaultdict(list)

for row in data['processes']:
    # Option A: include the full datetime in the grouping
    # key = (row["process_id"], row["start_date"])

    # Option B: group by just the date (no time). Depends on your need.
    # If your plan is truly day-based, you can do:
    date_only = row["start_date"].date()
    key = (row["process_id"], date_only)

    grouped[key].append(row)


# 2) For each group, show total activities and sum of workloads
for (pid, dt), rows in grouped.items():
    # Count how many rows (activities)
    count_activities = len(rows)

    # Optionally sum the act_workload
    total_workload = sum(r.get("act_workload", 0) for r in rows)

    print(f"Process {pid}, Date {dt}")
    print(f"  -> Activities: {count_activities}")
    print(f"  -> Total workload: {total_workload}")
    print()
# Out:
# Process 201, Date 2024-11-25
#   -> Activities: 468
#   -> Total workload: 256800

# %%
from datetime import datetime
from typing import List, Optional

class Task:
    """
    Represents a schedulable task in the production system.

    Attributes:
      task_id (int): Unique identifier for the task.
      name (str): A short name or description of the task.
      workload (float): Duration the task requires (minutes, hours, etc.).
      mandatory_equip_count (int): How many equipment units of matching category
          must be allocated simultaneously (e.g., 1 isolator).
      optional_equip_count (int): How many additional optional equipment units
          can be allocated if available (0 if none).
      required_workers (int): How many workers are needed to perform this task
          (or how many worker "slots" must be filled).
      required_skill (str): Required worker skill/team name. 
          e.g. "opérateur", "Classificateur".
      start_earliest (datetime): Earliest possible start time (hard constraint).
      end_latest (datetime): Latest permissible end time (hard constraint).
      predecessor_ids (List[int]): List of task_ids that must finish
          before this task starts.
      zone_id (int): Optional zone in which the task occurs (if relevant).
      sequence (int): A numeric sequence index (if tasks have a known order).
      category_equip (str): Equipment category needed (e.g., "LYO", "ISOLATOR").
      priority (int): Optional priority level; a smaller number might
          mean higher priority. (Newly added)
      due_date (datetime): Optional due date to finish this task; 
          could be used for an objective function or constraints. (Newly added)
      comments (str): Optional free-text field for notes. (Newly added)
    """

    def __init__(
        self,
        process_id,
        process_name,
        task_id: int,
        name: str,
        workload: float,
        # Equipment constraints
        mandatory_equip_count: int = 0,
        optional_equip_count: int = 0,
        # Worker constraints
        required_workers: int = 0,
        required_skill: Optional[str] = None,
        # Time constraints
        start_earliest: Optional[datetime] = None,
        end_latest: Optional[datetime] = None,
        # Precedence constraints
        predecessor_ids: Optional[List[int]] = None,
        # Spatial / zone
        zone_id: Optional[int] = None,
        # Sequence
        sequence: Optional[int] = None,
        # Equipment category
        category_equip: Optional[str] = None,
        # Additional fields
        priority: Optional[int] = None,
        due_date: Optional[datetime] = None,
        comments: Optional[str] = None
    ):
        self.process_id = process_id
        self.process_name = process_name
        self.task_id = task_id
        self.name = name
        self.workload = workload

        self.mandatory_equip_count = mandatory_equip_count
        self.optional_equip_count = optional_equip_count

        self.required_workers = required_workers
        self.required_skill = required_skill

        self.start_earliest = start_earliest
        self.end_latest = end_latest
        self.predecessor_ids = predecessor_ids if predecessor_ids else []

        self.zone_id = zone_id
        self.sequence = sequence
        self.category_equip = category_equip

        # Newly added attributes
        self.priority = priority
        self.due_date = due_date
        self.comments = comments

    def __repr__(self):
        return (
            f"Task(task_id={self.task_id}, name='{self.name}', "
            f"workload={self.workload}, "
            f"equip_counts=[{self.mandatory_equip_count}-"
            f"{self.mandatory_equip_count + self.optional_equip_count}], "
            f"required_workers={self.required_workers}, skill={self.required_skill}, "
            f"earliest={self.start_earliest}, latest={self.end_latest}, "
            f"predecessors={self.predecessor_ids}, zone_id={self.zone_id}, "
            f"sequence={self.sequence}, category_equip={self.category_equip}, "
            f"priority={self.priority}, due_date={self.due_date}, "
            f"comments='{self.comments}')"
        )

class Resource:
    """
    Represents a resource in the production system, such as a worker or equipment.

    Attributes:
      resource_id (int): Unique identifier for the resource.
      resource_type (str): Type of resource, e.g. "WORKER", "EQUIPMENT", or "ZONE".
      name (str): Name or label for the resource.
      capacity (int): If this resource can handle multiple tasks at once
          (e.g., a machine that runs 2 lines simultaneously). Usually 1.
      shifts (List[tuple]): For WORKER, a list of (start_min, end_min, date)
          specifying availability windows. For equipment, can store maintenance
          windows or downtime similarly if needed.
      skills (List[str]): If this is a worker, store any skills
          (e.g., ["opérateur", "Classificateur"]).
      equipment_category (str): If this is an equipment resource,
          store the equipment's category (e.g., "LYO", "ISOLATOR"). (Newly added)
      location (str): Optional text specifying the resource's location
          or department. (Newly added)
      notes (str): Optional free-text field for extra info. (Newly added)
    """

    def __init__(
        self,
        resource_id: int,
        resource_type: str,
        name: str,
        capacity: int = 1,
        shifts: Optional[List] = None,
        skills: Optional[List[str]] = None,
        # Newly added
        equipment_category: Optional[str] = None,
        location: Optional[str] = None,
        notes: Optional[str] = None
    ):
        self.resource_id = resource_id
        self.resource_type = resource_type
        self.name = name
        self.capacity = capacity

        self.shifts = shifts if shifts else []
        self.skills = skills if skills else []

        # For equipment
        self.equipment_category = equipment_category
        # Additional
        self.location = location
        self.notes = notes

    def __repr__(self):
        return (
            f"Resource(id={self.resource_id}, type={self.resource_type}, "
            f"name='{self.name}', capacity={self.capacity}, "
            f"skills={self.skills}, equipment_category={self.equipment_category}, "
            f"location='{self.location}', notes='{self.notes}')"
        )

# %%
import json
from datetime import datetime
from typing import Dict, Any, List, Optional

# Assume you have your enhanced data classes in the same file or imported:
# from my_data_classes import Task, Resource

def build_tasks_and_resources(data: Dict[str, Any]):
    """
    Converts raw dictionary data into lists of Task and Resource objects,
    with no reference-date logic. We keep datetime fields as-is.

    data is expected to have:
      - data["processes"] (list of process/activity rows)
      - data["equipment"] (list of equipment rows)
      - data["zones"] (list of zone rows)
      - data["workers"] (dict {worker_id: {...}})
      - data["shifts"] (dict {worker_id: [(start_min, end_min, shift_date), ...]})

    Returns:
      tasks: List[Task]
      resources: List[Resource]
    """

    # -------------------------------------------------------------------------
    # 1) Parse Tasks from data["processes"]
    #    Potentially, multiple rows can share the same act_id with different
    #    resource references. We'll accumulate them in a dict keyed by act_id.
    # -------------------------------------------------------------------------
    tasks_dict = {}

    for row in data["processes"]:
        act_id = row["act_id"]

        if act_id not in tasks_dict:
            # Initialize a skeletal dictionary for this task
            tasks_dict[act_id] = {
                "process_id": row["process_id"],
                "process_name": row["process_name"],
                "task_id": act_id,
                "name": str(row["act_name"]),
                "workload": row.get("act_workload", 0) or 0,
                "mandatory_equip_count": 0,
                "optional_equip_count": 0,
                "required_workers": 0,
                "required_skill": None,
                "start_earliest": row.get("start_date", None),   # keep as datetime
                "end_latest": row.get("end_date", None),         # keep as datetime
                "predecessor_ids": [],
                "zone_id": None,
                "sequence": row.get("pra_seq", None),
                "category_equip": row.get("equipment_category", None),
            }

            # Parse any "requiredWorkers" JSON to detect how many
            # workers or what skill might be needed
            try:
                workers_json = json.loads(row.get("requiredWorkers", "[]"))
                total_req_workers = 0
                skill_detected = None
                for wj in workers_json:
                    # e.g. if wj["RE_TYPE"] == "TEAM":
                    total_req_workers += wj.get("ACR_QTY", 0)
                    # skill might come from wj["RE_NAME"], e.g. "opérateur"
                    if not skill_detected and "RE_NAME" in wj:
                        skill_detected = wj["RE_NAME"]
                tasks_dict[act_id]["required_workers"] = total_req_workers
                tasks_dict[act_id]["required_skill"]   = skill_detected

            except json.JSONDecodeError:
                pass

        # Now parse resource references from the row:
        resource_type = row["resource_type"]
        resource_option = row.get("resource_option", "auto")

        if resource_type == "EQUIPEMENT":
            # If resource_option == "required", increment mandatory
            if resource_option == "required":
                tasks_dict[act_id]["mandatory_equip_count"] += 1
            else:
                tasks_dict[act_id]["optional_equip_count"]  += 1

        elif resource_type == "ZONE":
            # We can store the zone_id if not already set
            if tasks_dict[act_id]["zone_id"] is None:
                tasks_dict[act_id]["zone_id"] = row["resource_id"]

        elif resource_type == "TEAM":
            # Possibly we already accounted for it in requiredWorkers JSON
            pass

        # If you have any "predecessor" logic in these rows,
        # you could append them here:
        # predecessor_val = row.get("some_predecessor_column")
        # if predecessor_val:
        #     tasks_dict[act_id]["predecessor_ids"].append(predecessor_val)

    # Convert tasks_dict → list of Task objects
    tasks = []
    for act_id, td in tasks_dict.items():
        t = Task(
            process_id           = td["process_id"],
            process_name         = td["process_name"],
            task_id              = td["task_id"],
            name                 = td["name"],
            workload             = td["workload"],
            mandatory_equip_count= td["mandatory_equip_count"],
            optional_equip_count = td["optional_equip_count"],
            required_workers     = td["required_workers"],
            required_skill       = td["required_skill"],
            start_earliest       = td["start_earliest"],  # kept as raw datetime
            end_latest           = td["end_latest"],      # kept as raw datetime
            predecessor_ids      = td["predecessor_ids"],
            zone_id              = td["zone_id"],
            sequence             = td["sequence"],
            category_equip       = td["category_equip"]
        )
        tasks.append(t)

    # -------------------------------------------------------------------------
    # 2) Build Resource objects from equipment, zones, workers
    # -------------------------------------------------------------------------
    resources: List[Resource] = []

    # (A) Equipment
    for eq_row in data.get("equipment", []):
        r = Resource(
            resource_id       = eq_row["equipment_id"],
            resource_type     = "EQUIPMENT",
            name              = eq_row["equipment_name"],
            capacity          = 1,  # or parse if data has a capacity
            shifts            = None,  # often no shift data for eq
            skills            = None,
            equipment_category= eq_row.get("category", None),
            location          = None,
            notes             = None
        )
        resources.append(r)

    # (B) Zones
    for z_row in data.get("zones", []):
        r = Resource(
            resource_id       = z_row["zone_id"],
            resource_type     = "ZONE",
            name              = z_row["zone_name"],
            capacity          = 1,
            shifts            = None,
            skills            = None,
            equipment_category= z_row.get("category", None),
            location          = None,
            notes             = None
        )
        resources.append(r)

    # (C) Workers
    # data["workers"] is a dict: { worker_id -> {...} }
    # data["shifts"] is: { worker_id -> [(start_min, end_min, shift_date), ...] }
    for w_id, w_info in data.get("workers", {}).items():
        # We'll interpret w_info["team_name"] as their skill, etc.
        skill_list = []
        if w_info.get("team_name"):
            skill_list = [ w_info["team_name"] ]

        # Grab shift data as is—no day0 offset
        shift_data = data.get("shifts", {}).get(w_id, [])

        r = Resource(
            resource_id       = w_id,
            resource_type     = "WORKER",
            name              = f"Worker {w_id}",
            capacity          = 1,
            shifts            = shift_data,
            skills            = skill_list,
            equipment_category= None,
            location          = None,
            notes             = None
        )
        resources.append(r)

    # Done
    return tasks, resources

# %%
tasks, resources = build_tasks_and_resources(data)

# %%
tasks[:5], resources[:-5]
# Out:
# ([Task(task_id=520, name='25EE691F-55A4-41D1-9166-589E27EE6AC6', workload=600, equip_counts=[24-72], required_workers=5, skill=opérateur, earliest=2024-11-25 01:20:00, latest=2024-11-25 22:00:00, predecessors=[], zone_id=926, sequence=1, category_equip=UNDEFINED, priority=None, due_date=None, comments='None'),
#   Task(task_id=523, name='76E93EB2-61ED-4050-8D37-CE2AE59643B5', workload=1140, equip_counts=[0-48], required_workers=0, skill=None, earliest=2024-11-25 01:20:00, latest=2024-11-25 22:00:00, predecessors=[], zone_id=None, sequence=2, category_equip=UNDEFINED, priority=None, due_date=None, comments='None'),
#   Task(task_id=521, name='F9F78CF9-8687-41BB-BE2E-C6628E47F1AB', workload=120, equip_counts=[24-24], required_workers=1, skill=opérateur, earliest=2024-11-25 01:20:00, latest=2024-11-25 22:00:00, predecessors=[], zone_id=927, sequence=3, category_equip=UNDEFINED, priority=None, due_date=None, comments='None'),
#   Task(task_id=518, name='E8546E33-CAD5-45E2-ADBC-7D9EF6BFD9DB', workload=540, equip_counts=[0-108], required_workers=6, skill=opérateur, earliest=2024-11-25 01:20:00, latest=2024-11-25 22:00:00, predecessors=[], zone_id=927, sequence=4, category_equip=UNDEFINED, priority=None, due_date=None, comments='None'),
#   Task(task_id=519, name='B0377790-5CB6-42D2-8497-2D075B50BA58', workload=160, equip_counts=[12-60], required_workers=6, skill=opérateur, earliest=2024-11-25 01:20:00, latest=2024-11-25 22:00:00, predecessors=[], zone_id=927, sequence=5, category_equip=UNDEFINED, priority=None, due_date=None, comments='None')],
#  [Resource(id=930, type=EQUIPMENT, name='L8 - 2 - Intervention maint Corr L1', capacity=1, skills=[], equipment_category=UNDEFINED, location='None', notes='None'),
#   Resource(id=931, type=EQUIPMENT, name='L9 - 2 - Intervention maint Corr L2', capacity=1, skills=[], equipment_category=UNDEFINED, location='None', notes='None'),
#   Resource(id=932, type=EQUIPMENT, name='L1 - 01 - Isolateur Bosch', capacity=1, skills=[], equipment_category=UNDEFINED, location='None', notes='None'),
#   Resource(id=933, type=EQUIPMENT, name='L1 - 02 - Isolateur SKAN', capacity=1, skills=[], equipment_category=UNDEFINED, location='None', notes='None'),
#   Resource(id=934, type=EQUIPMENT, name='L1 - 03 - LYO A', capacity=1, skills=[], equipment_category=UNDEFINED, location='None', notes='None'),
#   Resource(id=935, type=EQUIPMENT, name='L1 - 04 - LYO B', capacity=1, skills=[], equipment_category=UNDEFINED, location='None', notes='None'),
#   Resource(id=936, type=EQUIPMENT, name='L1 - 05 - LYO C', capacity=1, skills=[], equipment_category=UNDEFINED, location='None', notes='None'),
#   Resource(id=937, type=EQUIPMENT, name='L1 - 06 -  LYO D', capacity=1, skills=[], equipment_category=UNDEFINED, location='None', notes='None'),
#   Resource(id=938, type=EQUIPMENT, name='L1 - 09 - Capsuleuse 1.1', capacity=1, skills=[], equipment_category=UNDEFINED, location='None', notes='None'),
#   Resource(id=939, type=EQUIPMENT, name='L1 - 11 - SEIDENADER', capacity=1, skills=[], equipment_category=UNDEFINED, location='None', notes='None'),
#   Resource(id=940, type=EQUIPMENT, name='L1 - 07 - DFT 1', capacity=1, skills=[], equipment_category=UNDEFINED, location='None', notes='None'),
#   Resource(id=941, type=EQUIPMENT, name='L1 - 10 - Capsuleuse 1.2', capacity=1, skills=[], equipment_category=UNDEFINED, location='None', notes='None'),
#   Resource(id=942, type=EQUIPMENT, name='L1 - 08 - DFT 2', capacity=1, skills=[], equipment_category=UNDEFINED, location='None', notes='None'),
#   Resource(id=943, type=EQUIPMENT, name='L2 - 20 - Capsuleuse 2.1', capacity=1, skills=[], equipment_category=UNDEFINED, location='None', notes='None'),
#   Resource(id=944, type=EQUIPMENT, name='L2 - 21 - Capsuleuse 2.2', capacity=1, skills=[], equipment_category=UNDEFINED, location='None', notes='None'),
#   Resource(id=945, type=EQUIPMENT, name='L2 - 12 - Isolateur Bosch', capacity=1, skills=[], equipment_category=UNDEFINED, location='None', notes='None'),
#   Resource(id=946, type=EQUIPMENT, name='L2 - 13 - Isolateur Skan', capacity=1, skills=[], equipment_category=UNDEFINED, location='None', notes='None'),
#   Resource(id=947, type=EQUIPMENT, name='L2 - 14 - LYO E', capacity=1, skills=[], equipment_category=UNDEFINED, location='None', notes='None'),
#   Resource(id=948, type=EQUIPMENT, name='L2 - 15 - LYO F', capacity=1, skills=[], equipment_category=UNDEFINED, location='None', notes='None'),
#   Resource(id=949, type=EQUIPMENT, name='L2 - 16 - LYO G', capacity=1, skills=[], equipment_category=UNDEFINED, location='None', notes='None'),
#   Resource(id=950, type=EQUIPMENT, name='L2 - 17 - LYO H', capacity=1, skills=[], equipment_category=UNDEFINED, location='None', notes='None'),
#   Resource(id=951, type=EQUIPMENT, name='L2 - 18 - DFT 3', capacity=1, skills=[], equipment_category=UNDEFINED, location='None', notes='None'),
#   Resource(id=952, type=EQUIPMENT, name='L2 - 19 - DFT 4', capacity=1, skills=[], equipment_category=UNDEFINED, location='None', notes='None'),
#   Resource(id=953, type=EQUIPMENT, name='L2 - 22 - Seidenader', capacity=1, skills=[], equipment_category=UNDEFINED, location='None', notes='None'),
#   Resource(id=954, type=EQUIPMENT, name='L2 - 11 - Taches annexes', capacity=1, skills=[], equipment_category=UNDEFINED, location='None', notes='None'),
#   Resource(id=955, type=EQUIPMENT, name='L1 - 00 - Suivi cuve', capacity=1, skills=[], equipment_category=UNDEFINED, location='None', notes='None'),
#   Resource(id=956, type=EQUIPMENT, name='L1 - 00 - Taches annexes', capacity=1, skills=[], equipment_category=UNDEFINED, location='None', notes='None'),
#   Resource(id=957, type=EQUIPMENT, name='L2 - 00 - Suivi cuve', capacity=1, skills=[], equipment_category=UNDEFINED, location='None', notes='None'),
#   Resource(id=926, type=ZONE, name='Ligne 1 - Chargement', capacity=1, skills=[], equipment_category=UNDEFINED, location='None', notes='None'),
#   Resource(id=927, type=ZONE, name='Ligne 1 - Déchargement', capacity=1, skills=[], equipment_category=UNDEFINED, location='None', notes='None'),
#   Resource(id=928, type=ZONE, name='Ligne 2 - Chargement', capacity=1, skills=[], equipment_category=UNDEFINED, location='None', notes='None'),
#   Resource(id=929, type=ZONE, name='Ligne 2 - Déchargement', capacity=1, skills=[], equipment_category=UNDEFINED, location='None', notes='None'),
#   Resource(id=1552, type=WORKER, name='Worker 1552', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1554, type=WORKER, name='Worker 1554', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1555, type=WORKER, name='Worker 1555', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1556, type=WORKER, name='Worker 1556', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1557, type=WORKER, name='Worker 1557', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1558, type=WORKER, name='Worker 1558', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1559, type=WORKER, name='Worker 1559', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1560, type=WORKER, name='Worker 1560', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1561, type=WORKER, name='Worker 1561', capacity=1, skills=['Classificateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1562, type=WORKER, name='Worker 1562', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1563, type=WORKER, name='Worker 1563', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1564, type=WORKER, name='Worker 1564', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1565, type=WORKER, name='Worker 1565', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1566, type=WORKER, name='Worker 1566', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1567, type=WORKER, name='Worker 1567', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1568, type=WORKER, name='Worker 1568', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1569, type=WORKER, name='Worker 1569', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1570, type=WORKER, name='Worker 1570', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1571, type=WORKER, name='Worker 1571', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1572, type=WORKER, name='Worker 1572', capacity=1, skills=['Classificateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1573, type=WORKER, name='Worker 1573', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1574, type=WORKER, name='Worker 1574', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1575, type=WORKER, name='Worker 1575', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1576, type=WORKER, name='Worker 1576', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1577, type=WORKER, name='Worker 1577', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1578, type=WORKER, name='Worker 1578', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1579, type=WORKER, name='Worker 1579', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1580, type=WORKER, name='Worker 1580', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1582, type=WORKER, name='Worker 1582', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1584, type=WORKER, name='Worker 1584', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1586, type=WORKER, name='Worker 1586', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1587, type=WORKER, name='Worker 1587', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1588, type=WORKER, name='Worker 1588', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1589, type=WORKER, name='Worker 1589', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1590, type=WORKER, name='Worker 1590', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1591, type=WORKER, name='Worker 1591', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1592, type=WORKER, name='Worker 1592', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1593, type=WORKER, name='Worker 1593', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1594, type=WORKER, name='Worker 1594', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1595, type=WORKER, name='Worker 1595', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1597, type=WORKER, name='Worker 1597', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1598, type=WORKER, name='Worker 1598', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1599, type=WORKER, name='Worker 1599', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1600, type=WORKER, name='Worker 1600', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1601, type=WORKER, name='Worker 1601', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1602, type=WORKER, name='Worker 1602', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1604, type=WORKER, name='Worker 1604', capacity=1, skills=['Classificateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1605, type=WORKER, name='Worker 1605', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1606, type=WORKER, name='Worker 1606', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1607, type=WORKER, name='Worker 1607', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1608, type=WORKER, name='Worker 1608', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1609, type=WORKER, name='Worker 1609', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1610, type=WORKER, name='Worker 1610', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1611, type=WORKER, name='Worker 1611', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1612, type=WORKER, name='Worker 1612', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1613, type=WORKER, name='Worker 1613', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1614, type=WORKER, name='Worker 1614', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1615, type=WORKER, name='Worker 1615', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1616, type=WORKER, name='Worker 1616', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1617, type=WORKER, name='Worker 1617', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1618, type=WORKER, name='Worker 1618', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1619, type=WORKER, name='Worker 1619', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1620, type=WORKER, name='Worker 1620', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1621, type=WORKER, name='Worker 1621', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1622, type=WORKER, name='Worker 1622', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1623, type=WORKER, name='Worker 1623', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1625, type=WORKER, name='Worker 1625', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1626, type=WORKER, name='Worker 1626', capacity=1, skills=['OP OS'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1627, type=WORKER, name='Worker 1627', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1628, type=WORKER, name='Worker 1628', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1629, type=WORKER, name='Worker 1629', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1630, type=WORKER, name='Worker 1630', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1631, type=WORKER, name='Worker 1631', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1632, type=WORKER, name='Worker 1632', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1633, type=WORKER, name='Worker 1633', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1634, type=WORKER, name='Worker 1634', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1635, type=WORKER, name='Worker 1635', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1636, type=WORKER, name='Worker 1636', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1637, type=WORKER, name='Worker 1637', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1638, type=WORKER, name='Worker 1638', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1639, type=WORKER, name='Worker 1639', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1640, type=WORKER, name='Worker 1640', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1641, type=WORKER, name='Worker 1641', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1642, type=WORKER, name='Worker 1642', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1643, type=WORKER, name='Worker 1643', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1644, type=WORKER, name='Worker 1644', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1645, type=WORKER, name='Worker 1645', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1647, type=WORKER, name='Worker 1647', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1648, type=WORKER, name='Worker 1648', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1649, type=WORKER, name='Worker 1649', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1650, type=WORKER, name='Worker 1650', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1651, type=WORKER, name='Worker 1651', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1652, type=WORKER, name='Worker 1652', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1653, type=WORKER, name='Worker 1653', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1654, type=WORKER, name='Worker 1654', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1655, type=WORKER, name='Worker 1655', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1656, type=WORKER, name='Worker 1656', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1657, type=WORKER, name='Worker 1657', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1658, type=WORKER, name='Worker 1658', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1659, type=WORKER, name='Worker 1659', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1660, type=WORKER, name='Worker 1660', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1661, type=WORKER, name='Worker 1661', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1662, type=WORKER, name='Worker 1662', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1663, type=WORKER, name='Worker 1663', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1664, type=WORKER, name='Worker 1664', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1665, type=WORKER, name='Worker 1665', capacity=1, skills=['Classificateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1667, type=WORKER, name='Worker 1667', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1668, type=WORKER, name='Worker 1668', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1669, type=WORKER, name='Worker 1669', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1670, type=WORKER, name='Worker 1670', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1671, type=WORKER, name='Worker 1671', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1672, type=WORKER, name='Worker 1672', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1673, type=WORKER, name='Worker 1673', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1674, type=WORKER, name='Worker 1674', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1675, type=WORKER, name='Worker 1675', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1676, type=WORKER, name='Worker 1676', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1677, type=WORKER, name='Worker 1677', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1678, type=WORKER, name='Worker 1678', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1679, type=WORKER, name='Worker 1679', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1680, type=WORKER, name='Worker 1680', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1681, type=WORKER, name='Worker 1681', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1682, type=WORKER, name='Worker 1682', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1684, type=WORKER, name='Worker 1684', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1685, type=WORKER, name='Worker 1685', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1688, type=WORKER, name='Worker 1688', capacity=1, skills=['OP OS'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1691, type=WORKER, name='Worker 1691', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1692, type=WORKER, name='Worker 1692', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1693, type=WORKER, name='Worker 1693', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1694, type=WORKER, name='Worker 1694', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1695, type=WORKER, name='Worker 1695', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1696, type=WORKER, name='Worker 1696', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1697, type=WORKER, name='Worker 1697', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1698, type=WORKER, name='Worker 1698', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1699, type=WORKER, name='Worker 1699', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1700, type=WORKER, name='Worker 1700', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1701, type=WORKER, name='Worker 1701', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1702, type=WORKER, name='Worker 1702', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1703, type=WORKER, name='Worker 1703', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1704, type=WORKER, name='Worker 1704', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1705, type=WORKER, name='Worker 1705', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1706, type=WORKER, name='Worker 1706', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1707, type=WORKER, name='Worker 1707', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1708, type=WORKER, name='Worker 1708', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1709, type=WORKER, name='Worker 1709', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1710, type=WORKER, name='Worker 1710', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1711, type=WORKER, name='Worker 1711', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1712, type=WORKER, name='Worker 1712', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1713, type=WORKER, name='Worker 1713', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1714, type=WORKER, name='Worker 1714', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1715, type=WORKER, name='Worker 1715', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1716, type=WORKER, name='Worker 1716', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1717, type=WORKER, name='Worker 1717', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1718, type=WORKER, name='Worker 1718', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1719, type=WORKER, name='Worker 1719', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1720, type=WORKER, name='Worker 1720', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1721, type=WORKER, name='Worker 1721', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None'),
#   Resource(id=1722, type=WORKER, name='Worker 1722', capacity=1, skills=['opérateur'], equipment_category=None, location='None', notes='None')])

# %%
# add zones to model:

from ortools.sat.python import cp_model
from typing import List, Dict, Any, Optional
from datetime import datetime, timedelta

def build_and_solve_schedule_model(
    tasks: List["Task"],         # Your pre-loaded tasks
    resources: List["Resource"], # Your pre-loaded resources
    time_unit: str = "minute",   # or "hour" if you prefer
    buffer_ratio: float = 0.2,   # 20% buffer on sum of workloads
    max_solver_time_s: float = 60.0
) -> (Dict[str, Any], Optional[int]):
    """
    Builds and solves a production-style CP-SAT scheduling model:

    Steps:
      1. Identify the global earliest datetime among all tasks (ignoring those w/o start_earliest).
      2. Convert all relevant datetimes to integer offsets from that global earliest.
      3. Compute horizon = sum_of_workloads + buffer.
      4. Define mandatory/optional equipment usage, equipment category matching,
         worker skill matching, earliest/latest constraints, precedence, no-overlap.
      5. Minimize makespan.
      6. Build final schedule:
         - schedule["by_task"]: info per task (start/end mapped back to real datetimes, etc.)
         - schedule["by_resource"]: intervals for each resource, sorted by start time.

    Returns:
      (schedule_dict, makespan_val)
        schedule_dict has keys "by_task" and "by_resource".
        makespan_val is the final schedule length in integer time units
                     (or None if infeasible).

    Note: If you want sub-minute or sub-hour resolution, you can multiply durations
          and do your own scaling logic. This code uses integer-based CP variables.
    """

    # ------------------------------------------------------------------
    # A) Identify the global earliest start among tasks
    #    We'll only consider tasks that have a non-None 'start_earliest'.
    # ------------------------------------------------------------------
    valid_starts = [t.start_earliest for t in tasks if t.start_earliest is not None]
    if valid_starts:
        global_earliest = min(valid_starts)
    else:
        # If no tasks have a start_earliest, just pick a reference
        global_earliest = datetime.now()

    # Helper to convert a datetime dt -> integer offset in minutes/hours from global_earliest
    def dt_to_int(dt: Optional[datetime]) -> int:
        if dt is None:
            # We'll treat no constraint as 0 or horizon-later, handle logic below
            return 0
        delta = dt - global_earliest
        minutes = int(delta.total_seconds() // 60)
        if time_unit == "minute":
            return minutes
        elif time_unit == "hour":
            return minutes // 60
        else:
            raise ValueError("Unsupported time_unit. Use 'minute' or 'hour'.")

    # ------------------------------------------------------------------
    # B) Compute sum_of_workloads + buffer as horizon
    #    We'll interpret 'task.workload' as integer minutes/hours
    # ------------------------------------------------------------------
    sum_workloads = 0
    for t in tasks:
        sum_workloads += int(t.workload)

    buffer_amount = int(buffer_ratio * sum_workloads)
    HORIZON = sum_workloads + buffer_amount
    if HORIZON < 1:
        HORIZON = 100_000  # must not be zero

    # ------------------------------------------------------------------
    # Separate resources by type
    # ------------------------------------------------------------------
    eq_list = [r for r in resources if r.resource_type == "EQUIPMENT"]
    wr_list = [r for r in resources if r.resource_type == "WORKER"]

    # ------------------------------------------------------------------
    # C) Build the CP model
    # ------------------------------------------------------------------
    model = cp_model.CpModel()

    # 1) Create interval variables for tasks
    task_vars = {}  # task_id -> (start_var, duration, end_var, interval_var)
    for t in tasks:
        duration = int(t.workload)
        start_var = model.NewIntVar(0, HORIZON, f"start_{t.task_id}")
        end_var   = model.NewIntVar(0, HORIZON, f"end_{t.task_id}")
        interval_var = model.NewIntervalVar(start_var, duration, end_var,
                                            f"interval_{t.task_id}")
        task_vars[t.task_id] = (start_var, duration, end_var, interval_var)

        # # If we want to enforce earliest start:
        # if t.start_earliest is not None:
        #     earliest_offset = dt_to_int(t.start_earliest)
        #     model.Add(start_var >= earliest_offset)

        # # If we want to enforce latest end:
        # if t.end_latest is not None:
        #     latest_offset = dt_to_int(t.end_latest)
        #     model.Add(end_var <= latest_offset)

    # 2) Equipment usage constraints
    equip_used = {}
    for t in tasks:
        for eq in eq_list:
            # Check equipment category match
            if t.category_equip and eq.equipment_category != t.category_equip:
                var = model.NewBoolVar(f"equip_used_{t.task_id}_{eq.resource_id}")
                model.Add(var == 0)
                equip_used[(t.task_id, eq.resource_id)] = var
            else:
                var = model.NewBoolVar(f"equip_used_{t.task_id}_{eq.resource_id}")
                equip_used[(t.task_id, eq.resource_id)] = var

    # Sum of equip booleans in [mand, mand + opt]
    for t in tasks:
        eq_ids = [eq.resource_id for eq in eq_list]
        model.Add(sum(equip_used[(t.task_id, e_id)] for e_id in eq_ids)
                  >= t.mandatory_equip_count)
        model.Add(sum(equip_used[(t.task_id, e_id)] for e_id in eq_ids)
                  <= t.mandatory_equip_count + t.optional_equip_count)

    # NoOverlap for each equipment
    eq_intervals_per_e = {eq.resource_id: [] for eq in eq_list}
    for t in tasks:
        (s_var, dur, e_var, interval_var) = task_vars[t.task_id]
        for eq in eq_list:
            bool_var = equip_used[(t.task_id, eq.resource_id)]
            opt_interval = model.NewOptionalIntervalVar(
                s_var, dur, e_var, bool_var,
                f"eq_opt_int_{t.task_id}_{eq.resource_id}"
            )
            eq_intervals_per_e[eq.resource_id].append(opt_interval)

    for eq in eq_list:
        model.AddNoOverlap(eq_intervals_per_e[eq.resource_id])

    # 3) Worker usage constraints (skill matching + exact number of workers)
    worker_used = {}
    for t in tasks:
        for w in wr_list:
            if t.required_skill and (t.required_skill not in w.skills):
                var = model.NewBoolVar(f"worker_used_{t.task_id}_{w.resource_id}")
                model.Add(var == 0)
                worker_used[(t.task_id, w.resource_id)] = var
            else:
                var = model.NewBoolVar(f"worker_used_{t.task_id}_{w.resource_id}")
                worker_used[(t.task_id, w.resource_id)] = var

    for t in tasks:
        w_ids = [wrk.resource_id for wrk in wr_list]
        model.Add(
            sum(worker_used[(t.task_id, w_id)] for w_id in w_ids)
            == t.required_workers
        )

    # NoOverlap for workers
    w_intervals_per_w = {w.resource_id: [] for w in wr_list}
    for t in tasks:
        (s_var, dur, e_var, interval_var) = task_vars[t.task_id]
        for w in wr_list:
            bool_var = worker_used[(t.task_id, w.resource_id)]
            opt_interval = model.NewOptionalIntervalVar(
                s_var, dur, e_var, bool_var,
                f"w_opt_int_{t.task_id}_{w.resource_id}"
            )
            w_intervals_per_w[w.resource_id].append(opt_interval)

    for w in wr_list:
        model.AddNoOverlap(w_intervals_per_w[w.resource_id])

    # 4) Precedence constraints
    for t in tasks:
        start_var, dur, end_var, interval_var = task_vars[t.task_id]
        for p_id in t.predecessor_ids:
            if p_id in task_vars:
                pred_end = task_vars[p_id][2]
                model.Add(start_var >= pred_end)

    # 5) Sequence constraints if tasks share the same zone + have a 'sequence'
    from collections import defaultdict
    zone_dict = defaultdict(list)
    for t in tasks:
        if t.zone_id is not None and t.sequence is not None:
            zone_dict[t.zone_id].append(t)

    for z_id, z_tasks in zone_dict.items():
        z_tasks_sorted = sorted(z_tasks, key=lambda x: x.sequence)
        for i in range(len(z_tasks_sorted) - 1):
            cur_t = z_tasks_sorted[i]
            nxt_t = z_tasks_sorted[i+1]
            cur_end = task_vars[cur_t.task_id][2]
            nxt_start = task_vars[nxt_t.task_id][0]
            model.Add(nxt_start >= cur_end)

    # 6) Minimize makespan
    all_end_vars = [task_vars[t.task_id][2] for t in tasks]
    makespan = model.NewIntVar(0, HORIZON, "makespan")
    model.AddMaxEquality(makespan, all_end_vars)
    model.Minimize(makespan)

    # ------------------------------------------------------------------
    # D) Solve the model
    # ------------------------------------------------------------------
    solver = cp_model.CpSolver()
    solver.parameters.max_time_in_seconds = max_solver_time_s
    status = solver.Solve(model)

    if status not in (cp_model.OPTIMAL, cp_model.FEASIBLE):
        print("No feasible solution found.")
        return {}, None

    print("Solver status:", solver.StatusName(status))

    # ------------------------------------------------------------------
    # E) Build final schedule output
    #    We'll provide:
    #      schedule["by_task"]
    #      schedule["by_resource"]
    # ------------------------------------------------------------------
    schedule = {
        "by_task": {},
        "by_resource": {}
    }

    # Initialize resource-lists
    for r in resources:
        schedule["by_resource"][r.resource_id] = []

    # Helper to map an integer offset back to a real datetime
    def int_to_dt(offset: int) -> datetime:
        if time_unit == "minute":
            return global_earliest + timedelta(minutes=offset)
        elif time_unit == "hour":
            return global_earliest + timedelta(hours=offset)
        else:
            raise ValueError("Unsupported time_unit. Use 'minute' or 'hour'.")

    # Fill "by_task"
    for t in tasks:
        (s_var, dur, e_var, _) = task_vars[t.task_id]
        start_val = solver.Value(s_var)
        end_val   = solver.Value(e_var)
        # map back to real-world dt
        real_start = int_to_dt(start_val)
        real_end   = int_to_dt(end_val)

        used_equip = []
        for eq in eq_list:
            if solver.Value(equip_used[(t.task_id, eq.resource_id)]) == 1:
                used_equip.append(eq.resource_id)

        used_workers = []
        for w in wr_list:
            if solver.Value(worker_used[(t.task_id, w.resource_id)]) == 1:
                used_workers.append(w.resource_id)

        schedule["by_task"][t.task_id] = {
            "process_id": t.process_id,
            "process_name": t.process_name,
            "task_id": t.task_id,
            "task_name": t.name,
            "start_int": start_val,
            "end_int": end_val,
            "start_optimized": real_start,
            "end_optimized": real_end,
            "used_equipment": used_equip,
            "used_workers": used_workers,
            "workload": t.workload,
            "team": t.required_skill,
            "sequence": t.sequence,
            "zone_id": t.zone_id,
            "initial_start": t.start_earliest,
            "initial_end": t.end_latest
        }

    # Fill "by_resource"
    for t in tasks:
        (s_var, _, e_var, _) = task_vars[t.task_id]
        start_val = solver.Value(s_var)
        end_val   = solver.Value(e_var)
        real_start = int_to_dt(start_val)
        real_end   = int_to_dt(end_val)

        # check equip usage
        for eq in eq_list:
            if solver.Value(equip_used[(t.task_id, eq.resource_id)]) == 1:
                schedule["by_resource"][eq.resource_id].append({
                    "task_id": t.task_id,
                    "task_name": t.name,
                    "start_int": start_val,
                    "end_int": end_val,
                    "start_optimized": real_start,
                    "end_optimized": real_end,
                    "initial_start": t.start_earliest,
                    "initial_end": t.end_latest,
                    "mandatory_count": t.mandatory_equip_count,
                    "optional_count" : t.optional_equip_count,
                })

        # check worker usage
        for w in wr_list:
            if solver.Value(worker_used[(t.task_id, w.resource_id)]) == 1:
                schedule["by_resource"][w.resource_id].append({
                    "task_id": t.task_id,
                    "task_name": t.name,
                    "start_int": start_val,
                    "end_int": end_val,
                    "start_optimized": real_start,
                    "end_optimized": real_end,
                    "team": t.required_skill
                })

    # Sort each resource’s intervals by start_int for clarity
    for r_id, intervals in schedule["by_resource"].items():
        intervals.sort(key=lambda x: x["start_int"])

    makespan_val = solver.Value(makespan)
    print("Makespan (int) =", makespan_val)
    print("Makespan start_dt => end_dt =",
          int_to_dt(0), "=>", int_to_dt(makespan_val))

    return schedule, makespan_val

# %%
schedule, makespan_val = build_and_solve_schedule_model(tasks, resources)
# Out:
# Solver status: OPTIMAL
# Makespan (int) = 1500
# Makespan start_dt => end_dt = 2024-11-25 01:20:00 => 2024-11-26 02:20:00

# %%
schedule['by_resource']
# Out:
# {930: [{'task_id': 521,
#    'task_name': 'F9F78CF9-8687-41BB-BE2E-C6628E47F1AB',
#    'start_int': 600,
#    'end_int': 720,
#    'start_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 13, 20),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 24,
#    'optional_count': 0},
#   {'task_id': 519,
#    'task_name': 'B0377790-5CB6-42D2-8497-2D075B50BA58',
#    'start_int': 1260,
#    'end_int': 1420,
#    'start_optimized': datetime.datetime(2024, 11, 25, 22, 20),
#    'end_optimized': datetime.datetime(2024, 11, 26, 1, 0),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 12,
#    'optional_count': 48}],
#  931: [{'task_id': 520,
#    'task_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6',
#    'start_int': 0,
#    'end_int': 600,
#    'start_optimized': datetime.datetime(2024, 11, 25, 1, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 24,
#    'optional_count': 48},
#   {'task_id': 521,
#    'task_name': 'F9F78CF9-8687-41BB-BE2E-C6628E47F1AB',
#    'start_int': 600,
#    'end_int': 720,
#    'start_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 13, 20),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 24,
#    'optional_count': 0},
#   {'task_id': 519,
#    'task_name': 'B0377790-5CB6-42D2-8497-2D075B50BA58',
#    'start_int': 1260,
#    'end_int': 1420,
#    'start_optimized': datetime.datetime(2024, 11, 25, 22, 20),
#    'end_optimized': datetime.datetime(2024, 11, 26, 1, 0),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 12,
#    'optional_count': 48}],
#  932: [{'task_id': 520,
#    'task_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6',
#    'start_int': 0,
#    'end_int': 600,
#    'start_optimized': datetime.datetime(2024, 11, 25, 1, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 24,
#    'optional_count': 48},
#   {'task_id': 521,
#    'task_name': 'F9F78CF9-8687-41BB-BE2E-C6628E47F1AB',
#    'start_int': 600,
#    'end_int': 720,
#    'start_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 13, 20),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 24,
#    'optional_count': 0},
#   {'task_id': 519,
#    'task_name': 'B0377790-5CB6-42D2-8497-2D075B50BA58',
#    'start_int': 1260,
#    'end_int': 1420,
#    'start_optimized': datetime.datetime(2024, 11, 25, 22, 20),
#    'end_optimized': datetime.datetime(2024, 11, 26, 1, 0),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 12,
#    'optional_count': 48}],
#  933: [{'task_id': 520,
#    'task_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6',
#    'start_int': 0,
#    'end_int': 600,
#    'start_optimized': datetime.datetime(2024, 11, 25, 1, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 24,
#    'optional_count': 48},
#   {'task_id': 521,
#    'task_name': 'F9F78CF9-8687-41BB-BE2E-C6628E47F1AB',
#    'start_int': 600,
#    'end_int': 720,
#    'start_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 13, 20),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 24,
#    'optional_count': 0},
#   {'task_id': 519,
#    'task_name': 'B0377790-5CB6-42D2-8497-2D075B50BA58',
#    'start_int': 1260,
#    'end_int': 1420,
#    'start_optimized': datetime.datetime(2024, 11, 25, 22, 20),
#    'end_optimized': datetime.datetime(2024, 11, 26, 1, 0),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 12,
#    'optional_count': 48}],
#  934: [{'task_id': 520,
#    'task_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6',
#    'start_int': 0,
#    'end_int': 600,
#    'start_optimized': datetime.datetime(2024, 11, 25, 1, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 24,
#    'optional_count': 48},
#   {'task_id': 521,
#    'task_name': 'F9F78CF9-8687-41BB-BE2E-C6628E47F1AB',
#    'start_int': 600,
#    'end_int': 720,
#    'start_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 13, 20),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 24,
#    'optional_count': 0},
#   {'task_id': 519,
#    'task_name': 'B0377790-5CB6-42D2-8497-2D075B50BA58',
#    'start_int': 1260,
#    'end_int': 1420,
#    'start_optimized': datetime.datetime(2024, 11, 25, 22, 20),
#    'end_optimized': datetime.datetime(2024, 11, 26, 1, 0),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 12,
#    'optional_count': 48}],
#  935: [{'task_id': 520,
#    'task_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6',
#    'start_int': 0,
#    'end_int': 600,
#    'start_optimized': datetime.datetime(2024, 11, 25, 1, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 24,
#    'optional_count': 48},
#   {'task_id': 521,
#    'task_name': 'F9F78CF9-8687-41BB-BE2E-C6628E47F1AB',
#    'start_int': 600,
#    'end_int': 720,
#    'start_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 13, 20),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 24,
#    'optional_count': 0},
#   {'task_id': 519,
#    'task_name': 'B0377790-5CB6-42D2-8497-2D075B50BA58',
#    'start_int': 1260,
#    'end_int': 1420,
#    'start_optimized': datetime.datetime(2024, 11, 25, 22, 20),
#    'end_optimized': datetime.datetime(2024, 11, 26, 1, 0),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 12,
#    'optional_count': 48}],
#  936: [{'task_id': 520,
#    'task_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6',
#    'start_int': 0,
#    'end_int': 600,
#    'start_optimized': datetime.datetime(2024, 11, 25, 1, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 24,
#    'optional_count': 48},
#   {'task_id': 521,
#    'task_name': 'F9F78CF9-8687-41BB-BE2E-C6628E47F1AB',
#    'start_int': 600,
#    'end_int': 720,
#    'start_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 13, 20),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 24,
#    'optional_count': 0},
#   {'task_id': 519,
#    'task_name': 'B0377790-5CB6-42D2-8497-2D075B50BA58',
#    'start_int': 1260,
#    'end_int': 1420,
#    'start_optimized': datetime.datetime(2024, 11, 25, 22, 20),
#    'end_optimized': datetime.datetime(2024, 11, 26, 1, 0),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 12,
#    'optional_count': 48}],
#  937: [{'task_id': 520,
#    'task_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6',
#    'start_int': 0,
#    'end_int': 600,
#    'start_optimized': datetime.datetime(2024, 11, 25, 1, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 24,
#    'optional_count': 48},
#   {'task_id': 521,
#    'task_name': 'F9F78CF9-8687-41BB-BE2E-C6628E47F1AB',
#    'start_int': 600,
#    'end_int': 720,
#    'start_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 13, 20),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 24,
#    'optional_count': 0},
#   {'task_id': 519,
#    'task_name': 'B0377790-5CB6-42D2-8497-2D075B50BA58',
#    'start_int': 1260,
#    'end_int': 1420,
#    'start_optimized': datetime.datetime(2024, 11, 25, 22, 20),
#    'end_optimized': datetime.datetime(2024, 11, 26, 1, 0),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 12,
#    'optional_count': 48}],
#  938: [{'task_id': 520,
#    'task_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6',
#    'start_int': 0,
#    'end_int': 600,
#    'start_optimized': datetime.datetime(2024, 11, 25, 1, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 24,
#    'optional_count': 48},
#   {'task_id': 521,
#    'task_name': 'F9F78CF9-8687-41BB-BE2E-C6628E47F1AB',
#    'start_int': 600,
#    'end_int': 720,
#    'start_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 13, 20),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 24,
#    'optional_count': 0},
#   {'task_id': 519,
#    'task_name': 'B0377790-5CB6-42D2-8497-2D075B50BA58',
#    'start_int': 1260,
#    'end_int': 1420,
#    'start_optimized': datetime.datetime(2024, 11, 25, 22, 20),
#    'end_optimized': datetime.datetime(2024, 11, 26, 1, 0),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 12,
#    'optional_count': 48}],
#  939: [{'task_id': 520,
#    'task_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6',
#    'start_int': 0,
#    'end_int': 600,
#    'start_optimized': datetime.datetime(2024, 11, 25, 1, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 24,
#    'optional_count': 48},
#   {'task_id': 521,
#    'task_name': 'F9F78CF9-8687-41BB-BE2E-C6628E47F1AB',
#    'start_int': 600,
#    'end_int': 720,
#    'start_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 13, 20),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 24,
#    'optional_count': 0},
#   {'task_id': 519,
#    'task_name': 'B0377790-5CB6-42D2-8497-2D075B50BA58',
#    'start_int': 1260,
#    'end_int': 1420,
#    'start_optimized': datetime.datetime(2024, 11, 25, 22, 20),
#    'end_optimized': datetime.datetime(2024, 11, 26, 1, 0),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 12,
#    'optional_count': 48}],
#  940: [{'task_id': 520,
#    'task_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6',
#    'start_int': 0,
#    'end_int': 600,
#    'start_optimized': datetime.datetime(2024, 11, 25, 1, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 24,
#    'optional_count': 48},
#   {'task_id': 521,
#    'task_name': 'F9F78CF9-8687-41BB-BE2E-C6628E47F1AB',
#    'start_int': 600,
#    'end_int': 720,
#    'start_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 13, 20),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 24,
#    'optional_count': 0},
#   {'task_id': 519,
#    'task_name': 'B0377790-5CB6-42D2-8497-2D075B50BA58',
#    'start_int': 1260,
#    'end_int': 1420,
#    'start_optimized': datetime.datetime(2024, 11, 25, 22, 20),
#    'end_optimized': datetime.datetime(2024, 11, 26, 1, 0),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 12,
#    'optional_count': 48}],
#  941: [{'task_id': 520,
#    'task_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6',
#    'start_int': 0,
#    'end_int': 600,
#    'start_optimized': datetime.datetime(2024, 11, 25, 1, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 24,
#    'optional_count': 48},
#   {'task_id': 521,
#    'task_name': 'F9F78CF9-8687-41BB-BE2E-C6628E47F1AB',
#    'start_int': 600,
#    'end_int': 720,
#    'start_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 13, 20),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 24,
#    'optional_count': 0},
#   {'task_id': 519,
#    'task_name': 'B0377790-5CB6-42D2-8497-2D075B50BA58',
#    'start_int': 1260,
#    'end_int': 1420,
#    'start_optimized': datetime.datetime(2024, 11, 25, 22, 20),
#    'end_optimized': datetime.datetime(2024, 11, 26, 1, 0),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 12,
#    'optional_count': 48}],
#  942: [{'task_id': 520,
#    'task_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6',
#    'start_int': 0,
#    'end_int': 600,
#    'start_optimized': datetime.datetime(2024, 11, 25, 1, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 24,
#    'optional_count': 48},
#   {'task_id': 521,
#    'task_name': 'F9F78CF9-8687-41BB-BE2E-C6628E47F1AB',
#    'start_int': 600,
#    'end_int': 720,
#    'start_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 13, 20),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 24,
#    'optional_count': 0}],
#  943: [{'task_id': 520,
#    'task_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6',
#    'start_int': 0,
#    'end_int': 600,
#    'start_optimized': datetime.datetime(2024, 11, 25, 1, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 24,
#    'optional_count': 48},
#   {'task_id': 521,
#    'task_name': 'F9F78CF9-8687-41BB-BE2E-C6628E47F1AB',
#    'start_int': 600,
#    'end_int': 720,
#    'start_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 13, 20),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 24,
#    'optional_count': 0}],
#  944: [{'task_id': 521,
#    'task_name': 'F9F78CF9-8687-41BB-BE2E-C6628E47F1AB',
#    'start_int': 600,
#    'end_int': 720,
#    'start_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 13, 20),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 24,
#    'optional_count': 0}],
#  945: [{'task_id': 520,
#    'task_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6',
#    'start_int': 0,
#    'end_int': 600,
#    'start_optimized': datetime.datetime(2024, 11, 25, 1, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 24,
#    'optional_count': 48},
#   {'task_id': 521,
#    'task_name': 'F9F78CF9-8687-41BB-BE2E-C6628E47F1AB',
#    'start_int': 600,
#    'end_int': 720,
#    'start_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 13, 20),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 24,
#    'optional_count': 0}],
#  946: [{'task_id': 520,
#    'task_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6',
#    'start_int': 0,
#    'end_int': 600,
#    'start_optimized': datetime.datetime(2024, 11, 25, 1, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 24,
#    'optional_count': 48},
#   {'task_id': 521,
#    'task_name': 'F9F78CF9-8687-41BB-BE2E-C6628E47F1AB',
#    'start_int': 600,
#    'end_int': 720,
#    'start_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 13, 20),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 24,
#    'optional_count': 0}],
#  947: [{'task_id': 520,
#    'task_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6',
#    'start_int': 0,
#    'end_int': 600,
#    'start_optimized': datetime.datetime(2024, 11, 25, 1, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 24,
#    'optional_count': 48},
#   {'task_id': 521,
#    'task_name': 'F9F78CF9-8687-41BB-BE2E-C6628E47F1AB',
#    'start_int': 600,
#    'end_int': 720,
#    'start_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 13, 20),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 24,
#    'optional_count': 0}],
#  948: [{'task_id': 520,
#    'task_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6',
#    'start_int': 0,
#    'end_int': 600,
#    'start_optimized': datetime.datetime(2024, 11, 25, 1, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 24,
#    'optional_count': 48},
#   {'task_id': 521,
#    'task_name': 'F9F78CF9-8687-41BB-BE2E-C6628E47F1AB',
#    'start_int': 600,
#    'end_int': 720,
#    'start_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 13, 20),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 24,
#    'optional_count': 0}],
#  949: [{'task_id': 520,
#    'task_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6',
#    'start_int': 0,
#    'end_int': 600,
#    'start_optimized': datetime.datetime(2024, 11, 25, 1, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 24,
#    'optional_count': 48},
#   {'task_id': 521,
#    'task_name': 'F9F78CF9-8687-41BB-BE2E-C6628E47F1AB',
#    'start_int': 600,
#    'end_int': 720,
#    'start_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 13, 20),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 24,
#    'optional_count': 0}],
#  950: [{'task_id': 520,
#    'task_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6',
#    'start_int': 0,
#    'end_int': 600,
#    'start_optimized': datetime.datetime(2024, 11, 25, 1, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 24,
#    'optional_count': 48},
#   {'task_id': 521,
#    'task_name': 'F9F78CF9-8687-41BB-BE2E-C6628E47F1AB',
#    'start_int': 600,
#    'end_int': 720,
#    'start_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 13, 20),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 24,
#    'optional_count': 0}],
#  951: [{'task_id': 520,
#    'task_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6',
#    'start_int': 0,
#    'end_int': 600,
#    'start_optimized': datetime.datetime(2024, 11, 25, 1, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 24,
#    'optional_count': 48},
#   {'task_id': 521,
#    'task_name': 'F9F78CF9-8687-41BB-BE2E-C6628E47F1AB',
#    'start_int': 600,
#    'end_int': 720,
#    'start_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 13, 20),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 24,
#    'optional_count': 0}],
#  952: [{'task_id': 520,
#    'task_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6',
#    'start_int': 0,
#    'end_int': 600,
#    'start_optimized': datetime.datetime(2024, 11, 25, 1, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 24,
#    'optional_count': 48},
#   {'task_id': 521,
#    'task_name': 'F9F78CF9-8687-41BB-BE2E-C6628E47F1AB',
#    'start_int': 600,
#    'end_int': 720,
#    'start_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 13, 20),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 24,
#    'optional_count': 0}],
#  953: [{'task_id': 520,
#    'task_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6',
#    'start_int': 0,
#    'end_int': 600,
#    'start_optimized': datetime.datetime(2024, 11, 25, 1, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 24,
#    'optional_count': 48},
#   {'task_id': 521,
#    'task_name': 'F9F78CF9-8687-41BB-BE2E-C6628E47F1AB',
#    'start_int': 600,
#    'end_int': 720,
#    'start_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 13, 20),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 24,
#    'optional_count': 0}],
#  954: [{'task_id': 520,
#    'task_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6',
#    'start_int': 0,
#    'end_int': 600,
#    'start_optimized': datetime.datetime(2024, 11, 25, 1, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 24,
#    'optional_count': 48}],
#  955: [{'task_id': 520,
#    'task_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6',
#    'start_int': 0,
#    'end_int': 600,
#    'start_optimized': datetime.datetime(2024, 11, 25, 1, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'initial_start': datetime.datetime(2024, 11, 25, 1, 20),
#    'initial_end': datetime.datetime(2024, 11, 25, 22, 0),
#    'mandatory_count': 24,
#    'optional_count': 48}],
#  956: [],
#  957: [],
#  926: [],
#  927: [],
#  928: [],
#  929: [],
#  1552: [{'task_id': 520,
#    'task_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6',
#    'start_int': 0,
#    'end_int': 600,
#    'start_optimized': datetime.datetime(2024, 11, 25, 1, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'team': 'opérateur'},
#   {'task_id': 518,
#    'task_name': 'E8546E33-CAD5-45E2-ADBC-7D9EF6BFD9DB',
#    'start_int': 720,
#    'end_int': 1260,
#    'start_optimized': datetime.datetime(2024, 11, 25, 13, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 22, 20),
#    'team': 'opérateur'},
#   {'task_id': 519,
#    'task_name': 'B0377790-5CB6-42D2-8497-2D075B50BA58',
#    'start_int': 1260,
#    'end_int': 1420,
#    'start_optimized': datetime.datetime(2024, 11, 25, 22, 20),
#    'end_optimized': datetime.datetime(2024, 11, 26, 1, 0),
#    'team': 'opérateur'}],
#  1554: [{'task_id': 520,
#    'task_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6',
#    'start_int': 0,
#    'end_int': 600,
#    'start_optimized': datetime.datetime(2024, 11, 25, 1, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'team': 'opérateur'},
#   {'task_id': 518,
#    'task_name': 'E8546E33-CAD5-45E2-ADBC-7D9EF6BFD9DB',
#    'start_int': 720,
#    'end_int': 1260,
#    'start_optimized': datetime.datetime(2024, 11, 25, 13, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 22, 20),
#    'team': 'opérateur'},
#   {'task_id': 519,
#    'task_name': 'B0377790-5CB6-42D2-8497-2D075B50BA58',
#    'start_int': 1260,
#    'end_int': 1420,
#    'start_optimized': datetime.datetime(2024, 11, 25, 22, 20),
#    'end_optimized': datetime.datetime(2024, 11, 26, 1, 0),
#    'team': 'opérateur'}],
#  1555: [{'task_id': 520,
#    'task_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6',
#    'start_int': 0,
#    'end_int': 600,
#    'start_optimized': datetime.datetime(2024, 11, 25, 1, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'team': 'opérateur'},
#   {'task_id': 518,
#    'task_name': 'E8546E33-CAD5-45E2-ADBC-7D9EF6BFD9DB',
#    'start_int': 720,
#    'end_int': 1260,
#    'start_optimized': datetime.datetime(2024, 11, 25, 13, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 22, 20),
#    'team': 'opérateur'},
#   {'task_id': 519,
#    'task_name': 'B0377790-5CB6-42D2-8497-2D075B50BA58',
#    'start_int': 1260,
#    'end_int': 1420,
#    'start_optimized': datetime.datetime(2024, 11, 25, 22, 20),
#    'end_optimized': datetime.datetime(2024, 11, 26, 1, 0),
#    'team': 'opérateur'}],
#  1556: [{'task_id': 520,
#    'task_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6',
#    'start_int': 0,
#    'end_int': 600,
#    'start_optimized': datetime.datetime(2024, 11, 25, 1, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'team': 'opérateur'},
#   {'task_id': 518,
#    'task_name': 'E8546E33-CAD5-45E2-ADBC-7D9EF6BFD9DB',
#    'start_int': 720,
#    'end_int': 1260,
#    'start_optimized': datetime.datetime(2024, 11, 25, 13, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 22, 20),
#    'team': 'opérateur'},
#   {'task_id': 519,
#    'task_name': 'B0377790-5CB6-42D2-8497-2D075B50BA58',
#    'start_int': 1260,
#    'end_int': 1420,
#    'start_optimized': datetime.datetime(2024, 11, 25, 22, 20),
#    'end_optimized': datetime.datetime(2024, 11, 26, 1, 0),
#    'team': 'opérateur'}],
#  1557: [{'task_id': 520,
#    'task_name': '25EE691F-55A4-41D1-9166-589E27EE6AC6',
#    'start_int': 0,
#    'end_int': 600,
#    'start_optimized': datetime.datetime(2024, 11, 25, 1, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'team': 'opérateur'},
#   {'task_id': 519,
#    'task_name': 'B0377790-5CB6-42D2-8497-2D075B50BA58',
#    'start_int': 1260,
#    'end_int': 1420,
#    'start_optimized': datetime.datetime(2024, 11, 25, 22, 20),
#    'end_optimized': datetime.datetime(2024, 11, 26, 1, 0),
#    'team': 'opérateur'}],
#  1558: [{'task_id': 519,
#    'task_name': 'B0377790-5CB6-42D2-8497-2D075B50BA58',
#    'start_int': 1260,
#    'end_int': 1420,
#    'start_optimized': datetime.datetime(2024, 11, 25, 22, 20),
#    'end_optimized': datetime.datetime(2024, 11, 26, 1, 0),
#    'team': 'opérateur'}],
#  1559: [],
#  1560: [],
#  1561: [],
#  1562: [],
#  1563: [],
#  1564: [],
#  1565: [],
#  1566: [],
#  1567: [],
#  1568: [],
#  1569: [],
#  1570: [],
#  1571: [],
#  1572: [],
#  1573: [],
#  1574: [],
#  1575: [],
#  1576: [],
#  1577: [],
#  1578: [],
#  1579: [],
#  1580: [],
#  1582: [],
#  1584: [],
#  1586: [],
#  1587: [],
#  1588: [],
#  1589: [],
#  1590: [],
#  1591: [],
#  1592: [],
#  1593: [],
#  1594: [],
#  1595: [],
#  1597: [],
#  1598: [],
#  1599: [],
#  1600: [],
#  1601: [],
#  1602: [],
#  1604: [],
#  1605: [],
#  1606: [],
#  1607: [],
#  1608: [],
#  1609: [],
#  1610: [],
#  1611: [],
#  1612: [],
#  1613: [],
#  1614: [],
#  1615: [],
#  1616: [],
#  1617: [],
#  1618: [],
#  1619: [],
#  1620: [],
#  1621: [],
#  1622: [],
#  1623: [],
#  1625: [],
#  1626: [],
#  1627: [],
#  1628: [],
#  1629: [],
#  1630: [],
#  1631: [],
#  1632: [],
#  1633: [],
#  1634: [],
#  1635: [],
#  1636: [],
#  1637: [],
#  1638: [],
#  1639: [],
#  1640: [],
#  1641: [],
#  1642: [],
#  1643: [],
#  1644: [],
#  1645: [],
#  1647: [],
#  1648: [],
#  1649: [],
#  1650: [],
#  1651: [],
#  1652: [],
#  1653: [],
#  1654: [],
#  1655: [],
#  1656: [],
#  1657: [],
#  1658: [],
#  1659: [],
#  1660: [],
#  1661: [],
#  1662: [],
#  1663: [],
#  1664: [],
#  1665: [],
#  1667: [],
#  1668: [],
#  1669: [],
#  1670: [],
#  1671: [],
#  1672: [],
#  1673: [],
#  1674: [],
#  1675: [],
#  1676: [],
#  1677: [],
#  1678: [],
#  1679: [],
#  1680: [],
#  1681: [],
#  1682: [],
#  1684: [],
#  1685: [],
#  1688: [],
#  1691: [],
#  1692: [],
#  1693: [],
#  1694: [],
#  1695: [],
#  1696: [],
#  1697: [],
#  1698: [],
#  1699: [],
#  1700: [],
#  1701: [{'task_id': 518,
#    'task_name': 'E8546E33-CAD5-45E2-ADBC-7D9EF6BFD9DB',
#    'start_int': 720,
#    'end_int': 1260,
#    'start_optimized': datetime.datetime(2024, 11, 25, 13, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 22, 20),
#    'team': 'opérateur'}],
#  1702: [],
#  1703: [{'task_id': 518,
#    'task_name': 'E8546E33-CAD5-45E2-ADBC-7D9EF6BFD9DB',
#    'start_int': 720,
#    'end_int': 1260,
#    'start_optimized': datetime.datetime(2024, 11, 25, 13, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 22, 20),
#    'team': 'opérateur'}],
#  1704: [],
#  1705: [],
#  1706: [],
#  1707: [],
#  1708: [],
#  1709: [],
#  1710: [],
#  1711: [],
#  1712: [],
#  1713: [],
#  1714: [],
#  1715: [],
#  1716: [],
#  1717: [],
#  1718: [],
#  1719: [],
#  1720: [],
#  1721: [],
#  1722: [],
#  1723: [],
#  1724: [],
#  1725: [],
#  1726: [{'task_id': 521,
#    'task_name': 'F9F78CF9-8687-41BB-BE2E-C6628E47F1AB',
#    'start_int': 600,
#    'end_int': 720,
#    'start_optimized': datetime.datetime(2024, 11, 25, 11, 20),
#    'end_optimized': datetime.datetime(2024, 11, 25, 13, 20),
#    'team': 'opérateur'}],
#  1727: []}
